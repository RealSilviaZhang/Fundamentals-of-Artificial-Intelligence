# %% [markdown]
# ## Code for solving 8-queens problem

# %% [markdown]
# ## Assignment Description
# Implement the Simulated Annealing algorithm and analyze the outcome in the setting of the 8-Queens problem. Explore different temperature schedules to study their impact on the algorithm’s effectiveness. The 8-Queens problem is a classic puzzle where the goal is to place eight queens on an 8×8 chessboard in such a way that no two queens threaten each other. This means no two queens can occupy the same row, column, or diagonal.
# There are three user-defined parameters in the program, namely, ‘temperature’, ‘epochs’, and ‘decay’.
# The usages are the following:
# - temperature: This is the starting temperature for the simulated annealing process. A higher initial temperature allows the algorithm to explore the solution space more freely at the beginning, potentially avoiding local minima. As the algorithm progresses, this temperature will gradually decrease.
# - epochs: This is the total number of iterations or steps the algorithm will run. Each epoch represents a single update of the algorithm, where it tries a new configuration of queens on the board. More epochs allow more thorough exploration but take longer to run.
# - decay ratio: This parameter determines how quickly the temperature decreases in each iteration of the algorithm. It is usually a value between 0 and 1 (not inclusive). A slower decay rate (closer to 1) means the temperature decreases more gradually, giving the algorithm more time to explore; a faster decay rate makes the temperature drop more quickly.rop more
# quickly.

# %% [markdown]
# ## Requirements

# %% [raw]
# • Implement the SimulatedAnnealing.run() function in the provided 8_queens.ipynb code to solve the 8-Queens problem. Complete the function within the code. (20 points)
# • The program uses a random initialization process for the positions of the 8 queens. To better observe how the program runs under different settings, please run the program 10 times for each of the following parameter combinations of temperature 𝑇, epochs 𝑒, and decay ratio 𝑑:
# - Setting I: 𝑇 = 4000, 𝑒 = 10000, 𝑑 = 0.9
# - Setting II: 𝑇 = 2000, 𝑒 = 10000, 𝑑 = 0.9
# - Setting III: 𝑇 = 1000, 𝑒 = 10000, 𝑑 = 0.9
# If you implement your program correctly, a typical successful sample output of the program is (the program uses the letter ‘Q’ to denote the queens):
# 1 Solution:
# 2 (0, 3)
# 3 (1, 5)
# 4 (2, 0)
# 5 (3, 4)
# 6 (4, 1)
# 7 (5, 7)
# 8 (6, 2)
# 9 (7, 6)
# 10
# 11 Success , Elapsed Time: 540.795ms
# 12
# 13 Initial Board:
# 14
# 15 . . Q . . . . .
# 16 . . . Q . . . .
# 17 . . . Q . . . .
# 18 . . . . Q . . .
# 19 . . . . . . . Q
# 20 . . . . . Q . .
# 21 . . . . . . . Q
# 22 . . . Q . . . .
# 23
# 24 Final Board:
# 25
# 26 . . . Q . . . .
# 27 . . . . . Q . .
# 28 Q . . . . . . .
# 29 . . . . Q . . .
# 30 . Q . . . . . .
# 31 . . . . . . . Q
# 32 . . Q . . . . .
# 33 . . . . . Q . .
# 34
# 35 Number of attacks: 0
# 36 Elapsed Time: 540.795ms
# A typical unsuccessful sample output of the program is:
# 1 Unsuccessful , Elapsed Time: 221.006 ms
# 2
# 3 Initial Board:
# 45 . . . . . . . Q
# 6 . . . . . . . Q
# 7 . . . . Q . . .
# 8 . . Q . . . . .
# 9 . . . Q . . . .
# 10 Q . . . . . . .
# 11 . . . . . . . Q
# 12 Q . . . . . . .
# 13
# 14 Final Board:
# 15
# 16 . . . . . Q . .
# 17 . . . . Q . . .
# 18 . . . . Q . . .
# 19 Q . . . . . . .
# 20 Q . . . . . . .
# 21 . Q . . . . . .
# 22 Q . . . . . . .
# 23 . . . Q . . . .
# 24
# 25 Number of attacks: 11
# 26 Elapsed Time: 221.006msickly.

# %% [raw]
# Present the performance of your algorithm for each experiment setting considering the success rate and the average time to convergence in the following table. You should include this table in your report. (10 points)
# Settings               Average Time to Covergence              Success Rate
# Setting I
# Setting II
# Setting III
# Table 1: Performance of the Simulated Annealing Algorithm under Difference Settings
#
# NOTE: Our code is tested on several OS and environment runtimes and is guaranteed to be executed

# %% [markdown]
# ## Submission Guidelines
# - Submit the Jupyter Notebook 8_queens.ipynb with your implementation of the simulated annealing function.
# - Submit a report with Table 1.
# - Ensure that your code is executable with the expected output.
# ## Assessment Criteria
# Your submission will be evaluated based on:
# - The correctness of your simulated annealing implementation.
# - The completeness of the result presented in the report.

# %%
# import libraries, you can add the decimal package if you need it
from datetime import datetime
import random, time, math
from copy import deepcopy, copy
from decimal import Decimal, getcontext

# %%
# define the board class, which will be used to store the state, visualize the board, and calculate the cost
class Board:
    def __init__(self, queen_count=8):
        self.queen_count = queen_count
        self.initial_queens = None  # Store the initial positions
        self.reset()

    def reset(self):
        self.queens = [-1 for i in range(0, self.queen_count)]
        for i in range(0, self.queen_count):
            self.queens[i] = random.randint(0, self.queen_count - 1)
        if self.initial_queens is None:
            self.initial_queens = self.queens.copy()  # Copy the initial positions

    def visualize(self):
        size = self.queen_count
        initial_board = [['.' for _ in range(size)] for _ in range(size)]
        final_board = [['.' for _ in range(size)] for _ in range(size)]

        # Populate the initial and final boards
        for row, col in enumerate(self.initial_queens):
            initial_board[row][col] = 'Q'
        for row, col in enumerate(self.queens):
            final_board[row][col] = 'Q'

        print("Initial Board:")
        for row in initial_board:
            print(" ".join(row))

        print("\nFinal Board:")
        for row in final_board:
            print(" ".join(row))

        print("\nNumber of attacks: ", self.calculateCost())

    def calculateCost(self):
        threat = 0

        for queen in range(0, self.queen_count):
            for next_queen in range(queen+1, self.queen_count):
                if self.queens[queen] == self.queens[next_queen] or abs(queen - next_queen) == abs(self.queens[queen] - self.queens[next_queen]):
                    threat += 1

        return threat

    def calculateCostWithQueens(queens):
        threat = 0
        queen_count = len(queens)

        for queen in range(0, queen_count):
            for next_queen in range(queen+1, queen_count):
                if queens[queen] == queens[next_queen] or abs(queen - next_queen) == abs(queens[queen] - queens[next_queen]):
                    threat += 1

        return threat

    def toString(queens):
        board_string = ""

        for row, col in enumerate(queens):
            board_string += "(%s, %s)\n" % (row, col)

        return board_string

    def __str__(self):
        board_string = ""

        for row, col in enumerate(self.queens):
            board_string += "(%s, %s)\n" % (row, col)

        return board_string

# %%
class SimulatedAnnealing:
    def __init__(self, board, param):
        self.elapsedTime = 0;
        self.board = board
        self.temperature = param['T']
        self.decay = param['decay']
        self.epochs = param['epochs']
        self.startTime = datetime.now()

    '''
    def run(self):
        board = self.board
        board_queens = self.board.queens[:]
        solutionFound = False
	
	    # Students should implement the following for loop
        # Hint: Iterate for a fixed number of times defined by 'self.epoches'
        # Inside the loop, implement the simulated annealing logic to find a solution
	
        for k in range(0, self.epochs):
            # Update temperature by multiplying with decay factor
            # Reset the board for the new iteration
            # Generate a new set of queen positions
            # Calculate the change in cost (dw) between the current and new positions
            # Calculate the probability of accepting the new positions
            # Decide whether to accept the new positions based on dw and the calculated probability
            # Check if a solution (no threats) is found, if so, print the solution and break the loop

        if solutionFound == False:
            self.elapsedTime = self.getElapsedTime()
            print("Unsuccessful, Elapsed Time: %sms" % (str(self.elapsedTime)))

        return self.elapsedTime
    
    def run(self):
        board = self.board
        board_queens = self.board.queens[:]
        solutionFound = False

        for k in range(0, self.epochs):
            temperature = self.temperature * (self.decay ** k)
            board.reset()
            new_queens = deepcopy(board_queens)
            i = random.randint(0, len(board_queens) - 1)
            new_queens[i] = random.randint(0, len(board_queens) - 1)
            self.board.queens = new_queens
            dw = self.board.calculateCost() - board.calculateCost()
            if temperature != 0:
                #scaling_factor = 10000000.0  # Fixed scaling factor
                #power_factor = 100000.0  # Fixed power factor
                #exp = math.exp(scaling_factor * dw / temperature) ** power_factor)
                exp = math.exp((-1) * dw / temperature)


                if dw < 0 or random.uniform(0, 1) < exp:
                    board_queens = new_queens

            if self.board.calculateCost() == 0:
                self.elapsedTime = self.getElapsedTime()
                print("Solution:")
                for i in range(len(board.queens)):
                    print(f"({i},{board.queens[i]})")
                print("\nSuccess , Elapsed Time: %sms\n" % (str(self.elapsedTime)))
                solutionFound = True
                break
                
        if solutionFound == False:
            self.elapsedTime = self.getElapsedTime()
            print("Unsuccessful, Elapsed Time: %sms" % (str(self.elapsedTime)))

        return self.elapsedTime
    '''
    def run(self):
        board = self.board
        board_queens = self.board.queens[:]
        solutionFound = False

        def get_threat_count(queen_pos):
            count = 0
            for i in range(len(board_queens)):
                if i == queen_pos:
                    continue
                if board_queens[i] == board_queens[queen_pos]:
                    count += 1
                elif abs(i - queen_pos) == abs(board_queens[i] - board_queens[queen_pos]):
                    count += 1
            return count

        for k in range(0, self.epochs):
            temperature = self.temperature * (self.decay ** k)
            board_queens = deepcopy(board_queens)

            # Choose a random queen with the maximum number of threats
            max_threats_queens = [
                i for i, q in enumerate(board_queens)
                if get_threat_count(i) == max(get_threat_count(j) for j in range(len(board_queens)))
            ]
            i = random.choice(max_threats_queens)

            # Find the position that minimizes the number of threats for the selected queen
            min_threats = get_threat_count(i)
            min_threats_pos = [board_queens[i]]

            for j in range(len(board_queens)):
                board_queens[i] = j
                threat_count = Board.calculateCostWithQueens(board_queens)  # Modified line

                if threat_count < min_threats:
                    min_threats = threat_count
                    min_threats_pos = [j]
                elif threat_count == min_threats:
                    min_threats_pos.append(j)

            # Move the queen to a random position that minimizes the number of threats
            board_queens[i] = random.choice(min_threats_pos)

            # Calculate the cost for the new board
            current_cost = board.calculateCost()
            new_cost = Board.calculateCostWithQueens(board_queens)

            # Update the board if the new board has a lower cost or with a certain probability
            if new_cost < current_cost or (temperature > 0 and random.random() <= math.exp((current_cost - new_cost) / temperature)):
                board.queens = deepcopy(board_queens)
                
            # Check if the solution is found
            if self.board.calculateCost() == 0:
                self.elapsedTime = self.getElapsedTime()
                print("Solution:")
                for i in range(len(board.queens)):
                    print(f"({i},{board.queens[i]})")
                print("\nSuccess , Elapsed Time: %sms\n" % (str(self.elapsedTime)))
                solutionFound = True
                break

        if solutionFound == False:
            self.elapsedTime = self.getElapsedTime()
            print("Unsuccessful, Elapsed Time: %sms" % (str(self.elapsedTime)))

        return self.elapsedTime


    def getElapsedTime(self):
        endTime = datetime.now()
        elapsedTime = (endTime - self.startTime).microseconds / 1000
        return elapsedTime

# %%
if __name__ == '__main__':
    board = Board()
    param = {'T': 4000, 'decay': 0.9, 'epochs': 10000}
    sa = SimulatedAnnealing(board, param)
    elapsed_time = sa.run()
    board.visualize()  # This will print the board state after the algorithm ends, regardless of success
    print("Elapsed Time: %sms" % str(elapsed_time))
# Out:
# Unsuccessful, Elapsed Time: 371.731ms
# Initial Board:
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
#
# Final Board:
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
#
# Number of attacks:  8
# Elapsed Time: 371.731ms

# %% [markdown]
# ## N = 10

# %%
param_settings = [
    {'T': 4000, 'epochs': 10000, 'decay': 0.9},  # Setting I
    {'T': 2000, 'epochs': 10000, 'decay': 0.9},  # Setting II
    {'T': 1000, 'epochs': 10000, 'decay': 0.9}   # Setting III
]

performance_table = []

itera = 10

for setting in param_settings:
    total_time = 0
    success_count = 0

    for _ in range(itera):
        board = Board()
        sa = SimulatedAnnealing(board, setting)
        elapsed_time = sa.run()

        if sa.board.calculateCost() == 0:
            total_time += elapsed_time
            success_count += 1
    if success_count != 0:
        avg_time = total_time / success_count
    else:
        avg_time = 0
    success_rate = success_count / itera

    performance_table.append((avg_time, success_rate))

# Print the performance table
print("Settings\t\tAverage Time to Convergence\tSuccess Rate")
for i, setting in enumerate(param_settings):
    avg_time, success_rate = performance_table[i]
    print(f"Setting {i+1}\t\t{avg_time:.3f}ms\t\t\t{success_rate * 100:.2f}%")
# Out:
# Solution:
# (0,2)
# (1,6)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 10.046ms
#
# Unsuccessful, Elapsed Time: 429.915ms
# Solution:
# (0,4)
# (1,6)
# (2,1)
# (3,5)
# (4,2)
# (5,0)
# (6,7)
# (7,3)
#
# Success , Elapsed Time: 5.811ms
#
# Unsuccessful, Elapsed Time: 332.646ms
# Unsuccessful, Elapsed Time: 355.003ms
# Unsuccessful, Elapsed Time: 354.805ms
# Unsuccessful, Elapsed Time: 420.875ms
# Unsuccessful, Elapsed Time: 398.074ms
# Unsuccessful, Elapsed Time: 415.836ms
# Unsuccessful, Elapsed Time: 434.194ms
# Unsuccessful, Elapsed Time: 352.107ms
# Unsuccessful, Elapsed Time: 507.615ms
# Unsuccessful, Elapsed Time: 591.115ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 6.095ms
#
# Unsuccessful, Elapsed Time: 457.328ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,1)
# (4,3)
# (5,7)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 1.81ms
#
# Unsuccessful, Elapsed Time: 338.351ms
# Unsuccessful, Elapsed Time: 343.519ms
# Unsuccessful, Elapsed Time: 334.889ms
# Unsuccessful, Elapsed Time: 299.786ms
# Unsuccessful, Elapsed Time: 362.759ms
# Unsuccessful, Elapsed Time: 341.855ms
# Unsuccessful, Elapsed Time: 264.863ms
# Solution:
# (0,3)
# (1,6)
# (2,0)
# (3,7)
# (4,4)
# (5,1)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 0.85ms
#
# Solution:
# (0,0)
# (1,6)
# (2,3)
# (3,5)
# (4,7)
# (5,1)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 1.364ms
#
# Unsuccessful, Elapsed Time: 301.252ms
# Unsuccessful, Elapsed Time: 353.306ms
# Unsuccessful, Elapsed Time: 333.788ms
# Unsuccessful, Elapsed Time: 333.904ms
# Unsuccessful, Elapsed Time: 374.118ms
# Settings		Average Time to Convergence	Success Rate
# Setting 1		7.928ms			20.00%
# Setting 2		3.952ms			20.00%
# Setting 3		1.107ms			20.00%

# %% [markdown]
# ## N = 100

# %%
param_settings = [
    {'T': 4000, 'epochs': 10000, 'decay': 0.9},  # Setting I
    {'T': 2000, 'epochs': 10000, 'decay': 0.9},  # Setting II
    {'T': 1000, 'epochs': 10000, 'decay': 0.9}   # Setting III
]

performance_table = []

itera = 100

for setting in param_settings:
    total_time = 0
    success_count = 0

    for _ in range(itera):
        board = Board()
        sa = SimulatedAnnealing(board, setting)
        elapsed_time = sa.run()

        if sa.board.calculateCost() == 0:
            total_time += elapsed_time
            success_count += 1
    if success_count != 0:
        avg_time = total_time / success_count
    else:
        avg_time = 0
    success_rate = success_count / itera

    performance_table.append((avg_time, success_rate))

# Print the performance table
print("Settings\t\tAverage Time to Convergence\tSuccess Rate")
for i, setting in enumerate(param_settings):
    avg_time, success_rate = performance_table[i]
    print(f"Setting {i+1}\t\t{avg_time:.3f}ms\t\t\t{success_rate * 100:.2f}%")
# Out:
# Unsuccessful, Elapsed Time: 316.117ms
# Unsuccessful, Elapsed Time: 288.961ms
# Unsuccessful, Elapsed Time: 351.796ms
# Unsuccessful, Elapsed Time: 301.192ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,1)
# (4,7)
# (5,4)
# (6,0)
# (7,3)
#
# Success , Elapsed Time: 60.451ms
#
# Unsuccessful, Elapsed Time: 328.582ms
# Unsuccessful, Elapsed Time: 357.774ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 10.72ms
#
# Unsuccessful, Elapsed Time: 364.282ms
# Unsuccessful, Elapsed Time: 360.173ms
# Unsuccessful, Elapsed Time: 318.103ms
# Unsuccessful, Elapsed Time: 302.695ms
# Unsuccessful, Elapsed Time: 305.59ms
# Unsuccessful, Elapsed Time: 319.119ms
# Unsuccessful, Elapsed Time: 279.291ms
# Unsuccessful, Elapsed Time: 305.584ms
# Unsuccessful, Elapsed Time: 335.555ms
# Unsuccessful, Elapsed Time: 302.964ms
# Solution:
# (0,4)
# (1,0)
# (2,7)
# (3,5)
# (4,2)
# (5,6)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 6.239ms
#
# Unsuccessful, Elapsed Time: 346.083ms
# Unsuccessful, Elapsed Time: 316.145ms
# Unsuccessful, Elapsed Time: 339.924ms
# Unsuccessful, Elapsed Time: 305.457ms
# Unsuccessful, Elapsed Time: 280.608ms
# Unsuccessful, Elapsed Time: 366.262ms
# Unsuccessful, Elapsed Time: 380.688ms
# Unsuccessful, Elapsed Time: 370.205ms
# Unsuccessful, Elapsed Time: 397.996ms
# Unsuccessful, Elapsed Time: 337.023ms
# Unsuccessful, Elapsed Time: 382.048ms
# Unsuccessful, Elapsed Time: 348.987ms
# Unsuccessful, Elapsed Time: 314.344ms
# Unsuccessful, Elapsed Time: 349.91ms
# Unsuccessful, Elapsed Time: 352.289ms
# Unsuccessful, Elapsed Time: 263.575ms
# Unsuccessful, Elapsed Time: 396.92ms
# Unsuccessful, Elapsed Time: 401.745ms
# Unsuccessful, Elapsed Time: 326.904ms
# Unsuccessful, Elapsed Time: 323.322ms
# Unsuccessful, Elapsed Time: 400.298ms
# Unsuccessful, Elapsed Time: 351.452ms
# Unsuccessful, Elapsed Time: 439.407ms
# Unsuccessful, Elapsed Time: 401.349ms
# Unsuccessful, Elapsed Time: 351.556ms
# Unsuccessful, Elapsed Time: 314.972ms
# Unsuccessful, Elapsed Time: 338.572ms
# Unsuccessful, Elapsed Time: 362.862ms
# Unsuccessful, Elapsed Time: 412.893ms
# Unsuccessful, Elapsed Time: 396.005ms
# Unsuccessful, Elapsed Time: 398.258ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,1)
# (4,3)
# (5,7)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 73.021ms
#
# Unsuccessful, Elapsed Time: 405.435ms
# Unsuccessful, Elapsed Time: 354.209ms
# Unsuccessful, Elapsed Time: 334.759ms
# Unsuccessful, Elapsed Time: 350.813ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,1)
# (4,6)
# (5,0)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 8.712ms
#
# Unsuccessful, Elapsed Time: 386.126ms
# Solution:
# (0,2)
# (1,5)
# (2,3)
# (3,0)
# (4,7)
# (5,4)
# (6,6)
# (7,1)
#
# Success , Elapsed Time: 6.655ms
#
# Solution:
# (0,5)
# (1,3)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,1)
# (7,7)
#
# Success , Elapsed Time: 1.435ms
#
# Unsuccessful, Elapsed Time: 326.441ms
# Unsuccessful, Elapsed Time: 338.914ms
# Unsuccessful, Elapsed Time: 366.555ms
# Unsuccessful, Elapsed Time: 341.728ms
# Unsuccessful, Elapsed Time: 404.628ms
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,7)
# (4,3)
# (5,1)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 9.107ms
#
# Unsuccessful, Elapsed Time: 302.073ms
# Unsuccessful, Elapsed Time: 306.814ms
# Solution:
# (0,2)
# (1,6)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 0.588ms
#
# Unsuccessful, Elapsed Time: 282.467ms
# Unsuccessful, Elapsed Time: 384.463ms
# Unsuccessful, Elapsed Time: 361.72ms
# Unsuccessful, Elapsed Time: 382.961ms
# Unsuccessful, Elapsed Time: 348.524ms
# Unsuccessful, Elapsed Time: 414.47ms
# Unsuccessful, Elapsed Time: 369.993ms
# Unsuccessful, Elapsed Time: 205.759ms
# Unsuccessful, Elapsed Time: 300.234ms
# Unsuccessful, Elapsed Time: 294.222ms
# Unsuccessful, Elapsed Time: 378.855ms
# Unsuccessful, Elapsed Time: 397.247ms
# Unsuccessful, Elapsed Time: 327.868ms
# Solution:
# (0,1)
# (1,4)
# (2,6)
# (3,0)
# (4,2)
# (5,7)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 1.662ms
#
# Unsuccessful, Elapsed Time: 270.623ms
# Unsuccessful, Elapsed Time: 407.309ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,3)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 2.202ms
#
# Unsuccessful, Elapsed Time: 407.427ms
# Unsuccessful, Elapsed Time: 417.844ms
# Unsuccessful, Elapsed Time: 419.542ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,4)
# (5,6)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 0.838ms
#
# Unsuccessful, Elapsed Time: 346.773ms
# Unsuccessful, Elapsed Time: 326.365ms
# Unsuccessful, Elapsed Time: 366.665ms
# Solution:
# (0,3)
# (1,1)
# (2,6)
# (3,2)
# (4,5)
# (5,7)
# (6,4)
# (7,0)
#
# Success , Elapsed Time: 11.079ms
#
# Unsuccessful, Elapsed Time: 351.585ms
# Unsuccessful, Elapsed Time: 314.186ms
# Unsuccessful, Elapsed Time: 417.579ms
# Unsuccessful, Elapsed Time: 413.521ms
# Unsuccessful, Elapsed Time: 406.683ms
# Unsuccessful, Elapsed Time: 361.049ms
# Unsuccessful, Elapsed Time: 394.961ms
# Unsuccessful, Elapsed Time: 362.745ms
# Unsuccessful, Elapsed Time: 302.559ms
# Unsuccessful, Elapsed Time: 389.605ms
# Unsuccessful, Elapsed Time: 410.446ms
# Unsuccessful, Elapsed Time: 479.862ms
# Unsuccessful, Elapsed Time: 228.19ms
# Unsuccessful, Elapsed Time: 471.005ms
# Unsuccessful, Elapsed Time: 499.64ms
# Unsuccessful, Elapsed Time: 472.853ms
# Unsuccessful, Elapsed Time: 484.299ms
# Solution:
# (0,4)
# (1,6)
# (2,1)
# (3,5)
# (4,2)
# (5,0)
# (6,7)
# (7,3)
#
# Success , Elapsed Time: 7.319ms
#
# Unsuccessful, Elapsed Time: 511.539ms
# Unsuccessful, Elapsed Time: 491.079ms
# Unsuccessful, Elapsed Time: 577.123ms
# Unsuccessful, Elapsed Time: 502.65ms
# Unsuccessful, Elapsed Time: 527.629ms
# Unsuccessful, Elapsed Time: 453.292ms
# Unsuccessful, Elapsed Time: 285.151ms
# Unsuccessful, Elapsed Time: 402.732ms
# Unsuccessful, Elapsed Time: 332.081ms
# Unsuccessful, Elapsed Time: 375.635ms
# Unsuccessful, Elapsed Time: 428.61ms
# Unsuccessful, Elapsed Time: 524.803ms
# Solution:
# (0,3)
# (1,7)
# (2,0)
# (3,4)
# (4,6)
# (5,1)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 1.604ms
#
# Unsuccessful, Elapsed Time: 548.805ms
# Unsuccessful, Elapsed Time: 416.347ms
# Solution:
# (0,4)
# (1,0)
# (2,3)
# (3,5)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 16.017ms
#
# Unsuccessful, Elapsed Time: 542.381ms
# Unsuccessful, Elapsed Time: 570.325ms
# Unsuccessful, Elapsed Time: 901.225ms
# Unsuccessful, Elapsed Time: 794.193ms
# Unsuccessful, Elapsed Time: 619.837ms
# Unsuccessful, Elapsed Time: 694.664ms
# Unsuccessful, Elapsed Time: 883.109ms
# Unsuccessful, Elapsed Time: 733.444ms
# Unsuccessful, Elapsed Time: 351.189ms
# Unsuccessful, Elapsed Time: 380.424ms
# Unsuccessful, Elapsed Time: 375.3ms
# Unsuccessful, Elapsed Time: 367.875ms
# Unsuccessful, Elapsed Time: 263.573ms
# Unsuccessful, Elapsed Time: 304.217ms
# Unsuccessful, Elapsed Time: 368.84ms
# Unsuccessful, Elapsed Time: 345.025ms
# Unsuccessful, Elapsed Time: 370.211ms
# Unsuccessful, Elapsed Time: 299.383ms
# Unsuccessful, Elapsed Time: 367.94ms
# Solution:
# (0,1)
# (1,5)
# (2,0)
# (3,6)
# (4,3)
# (5,7)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 6.976ms
#
# Unsuccessful, Elapsed Time: 372.268ms
# Unsuccessful, Elapsed Time: 347.853ms
# Solution:
# (0,6)
# (1,3)
# (2,1)
# (3,7)
# (4,5)
# (5,0)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 63.484ms
#
# Unsuccessful, Elapsed Time: 372.201ms
# Solution:
# (0,5)
# (1,1)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,7)
# (7,3)
#
# Success , Elapsed Time: 4.557ms
#
# Unsuccessful, Elapsed Time: 290.895ms
# Unsuccessful, Elapsed Time: 318.215ms
# Unsuccessful, Elapsed Time: 333.943ms
# Unsuccessful, Elapsed Time: 394.492ms
# Unsuccessful, Elapsed Time: 202.849ms
# Unsuccessful, Elapsed Time: 343.192ms
# Unsuccessful, Elapsed Time: 363.301ms
# Unsuccessful, Elapsed Time: 226.583ms
# Unsuccessful, Elapsed Time: 329.951ms
# Unsuccessful, Elapsed Time: 265.731ms
# Unsuccessful, Elapsed Time: 354.517ms
# Unsuccessful, Elapsed Time: 317.644ms
# Unsuccessful, Elapsed Time: 298.164ms
# Unsuccessful, Elapsed Time: 348.467ms
# Unsuccessful, Elapsed Time: 365.543ms
# Unsuccessful, Elapsed Time: 270.534ms
# Unsuccessful, Elapsed Time: 308.251ms
# Unsuccessful, Elapsed Time: 305.99ms
# Unsuccessful, Elapsed Time: 304.098ms
# Unsuccessful, Elapsed Time: 338.555ms
# Unsuccessful, Elapsed Time: 365.72ms
# Unsuccessful, Elapsed Time: 336.045ms
# Unsuccessful, Elapsed Time: 365.791ms
# Unsuccessful, Elapsed Time: 397.582ms
# Solution:
# (0,4)
# (1,6)
# (2,0)
# (3,3)
# (4,1)
# (5,7)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 60.412ms
#
# Unsuccessful, Elapsed Time: 255.771ms
# Unsuccessful, Elapsed Time: 359.317ms
# Unsuccessful, Elapsed Time: 344.519ms
# Unsuccessful, Elapsed Time: 318.931ms
# Unsuccessful, Elapsed Time: 355.558ms
# Unsuccessful, Elapsed Time: 338.631ms
# Unsuccessful, Elapsed Time: 364.191ms
# Unsuccessful, Elapsed Time: 386.421ms
# Unsuccessful, Elapsed Time: 398.888ms
# Unsuccessful, Elapsed Time: 334.319ms
# Unsuccessful, Elapsed Time: 283.222ms
# Unsuccessful, Elapsed Time: 382.059ms
# Unsuccessful, Elapsed Time: 396.248ms
# Unsuccessful, Elapsed Time: 373.652ms
# Unsuccessful, Elapsed Time: 331.698ms
# Unsuccessful, Elapsed Time: 400.537ms
# Unsuccessful, Elapsed Time: 364.798ms
# Unsuccessful, Elapsed Time: 319.245ms
# Unsuccessful, Elapsed Time: 316.893ms
# Unsuccessful, Elapsed Time: 365.333ms
# Unsuccessful, Elapsed Time: 312.768ms
# Unsuccessful, Elapsed Time: 349.996ms
# Unsuccessful, Elapsed Time: 370.03ms
# Solution:
# (0,3)
# (1,1)
# (2,7)
# (3,4)
# (4,6)
# (5,0)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 4.924ms
#
# Unsuccessful, Elapsed Time: 292.656ms
# Unsuccessful, Elapsed Time: 346.563ms
# Unsuccessful, Elapsed Time: 357.249ms
# Unsuccessful, Elapsed Time: 314.135ms
# Unsuccessful, Elapsed Time: 380.657ms
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,7)
# (4,4)
# (5,1)
# (6,3)
# (7,6)
#
# Success , Elapsed Time: 0.555ms
#
# Unsuccessful, Elapsed Time: 390.53ms
# Unsuccessful, Elapsed Time: 290.761ms
# Unsuccessful, Elapsed Time: 286.272ms
# Solution:
# (0,2)
# (1,0)
# (2,6)
# (3,4)
# (4,7)
# (5,1)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 4.973ms
#
# Unsuccessful, Elapsed Time: 393.24ms
# Unsuccessful, Elapsed Time: 362.872ms
# Solution:
# (0,4)
# (1,7)
# (2,3)
# (3,0)
# (4,6)
# (5,1)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 4.578ms
#
# Solution:
# (0,2)
# (1,0)
# (2,6)
# (3,4)
# (4,7)
# (5,1)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 4.135ms
#
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,7)
# (4,4)
# (5,1)
# (6,3)
# (7,6)
#
# Success , Elapsed Time: 9.662ms
#
# Unsuccessful, Elapsed Time: 287.453ms
# Unsuccessful, Elapsed Time: 368.722ms
# Unsuccessful, Elapsed Time: 401.474ms
# Unsuccessful, Elapsed Time: 336.317ms
# Solution:
# (0,5)
# (1,1)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,7)
# (7,3)
#
# Success , Elapsed Time: 17.975ms
#
# Unsuccessful, Elapsed Time: 269.884ms
# Unsuccessful, Elapsed Time: 410.628ms
# Solution:
# (0,7)
# (1,3)
# (2,0)
# (3,2)
# (4,5)
# (5,1)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 1.485ms
#
# Unsuccessful, Elapsed Time: 401.295ms
# Unsuccessful, Elapsed Time: 392.133ms
# Unsuccessful, Elapsed Time: 354.716ms
# Unsuccessful, Elapsed Time: 257.479ms
# Unsuccessful, Elapsed Time: 359.001ms
# Unsuccessful, Elapsed Time: 274.289ms
# Unsuccessful, Elapsed Time: 396.746ms
# Unsuccessful, Elapsed Time: 312.05ms
# Unsuccessful, Elapsed Time: 191.49ms
# Unsuccessful, Elapsed Time: 267.492ms
# Unsuccessful, Elapsed Time: 336.855ms
# Unsuccessful, Elapsed Time: 372.051ms
# Unsuccessful, Elapsed Time: 323.376ms
# Unsuccessful, Elapsed Time: 371.492ms
# Unsuccessful, Elapsed Time: 256.948ms
# Unsuccessful, Elapsed Time: 298.797ms
# Unsuccessful, Elapsed Time: 319.324ms
# Unsuccessful, Elapsed Time: 363.633ms
# Unsuccessful, Elapsed Time: 372.983ms
# Unsuccessful, Elapsed Time: 264.497ms
# Unsuccessful, Elapsed Time: 412.599ms
# Unsuccessful, Elapsed Time: 384.341ms
# Unsuccessful, Elapsed Time: 333.633ms
# Unsuccessful, Elapsed Time: 305.151ms
# Unsuccessful, Elapsed Time: 356.787ms
# Unsuccessful, Elapsed Time: 384.783ms
# Solution:
# (0,6)
# (1,3)
# (2,1)
# (3,7)
# (4,5)
# (5,0)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 4.658ms
#
# Solution:
# (0,1)
# (1,6)
# (2,2)
# (3,5)
# (4,7)
# (5,4)
# (6,0)
# (7,3)
#
# Success , Elapsed Time: 0.275ms
#
# Unsuccessful, Elapsed Time: 367.737ms
# Unsuccessful, Elapsed Time: 394.341ms
# Unsuccessful, Elapsed Time: 348.572ms
# Unsuccessful, Elapsed Time: 267.577ms
# Unsuccessful, Elapsed Time: 392.818ms
# Unsuccessful, Elapsed Time: 304.318ms
# Solution:
# (0,2)
# (1,4)
# (2,1)
# (3,7)
# (4,0)
# (5,6)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 23.06ms
#
# Unsuccessful, Elapsed Time: 216.381ms
# Unsuccessful, Elapsed Time: 392.194ms
# Unsuccessful, Elapsed Time: 369.971ms
# Unsuccessful, Elapsed Time: 352.011ms
# Unsuccessful, Elapsed Time: 372.898ms
# Unsuccessful, Elapsed Time: 333.815ms
# Unsuccessful, Elapsed Time: 329.189ms
# Unsuccessful, Elapsed Time: 343.414ms
# Unsuccessful, Elapsed Time: 292.073ms
# Unsuccessful, Elapsed Time: 353.789ms
# Unsuccessful, Elapsed Time: 372.585ms
# Solution:
# (0,1)
# (1,6)
# (2,2)
# (3,5)
# (4,7)
# (5,4)
# (6,0)
# (7,3)
#
# Success , Elapsed Time: 0.285ms
#
# Unsuccessful, Elapsed Time: 347.688ms
# Unsuccessful, Elapsed Time: 376.604ms
# Unsuccessful, Elapsed Time: 280.558ms
# Unsuccessful, Elapsed Time: 322.155ms
# Unsuccessful, Elapsed Time: 373.195ms
# Solution:
# (0,1)
# (1,7)
# (2,5)
# (3,0)
# (4,2)
# (5,4)
# (6,6)
# (7,3)
#
# Success , Elapsed Time: 3.644ms
#
# Unsuccessful, Elapsed Time: 323.006ms
# Unsuccessful, Elapsed Time: 359.697ms
# Unsuccessful, Elapsed Time: 282.483ms
# Unsuccessful, Elapsed Time: 368.854ms
# Solution:
# (0,7)
# (1,3)
# (2,0)
# (3,2)
# (4,5)
# (5,1)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 0.557ms
#
# Unsuccessful, Elapsed Time: 373.511ms
# Unsuccessful, Elapsed Time: 390.644ms
# Unsuccessful, Elapsed Time: 321.061ms
# Unsuccessful, Elapsed Time: 330.861ms
# Unsuccessful, Elapsed Time: 288.028ms
# Unsuccessful, Elapsed Time: 386.041ms
# Unsuccessful, Elapsed Time: 339.943ms
# Unsuccessful, Elapsed Time: 395.704ms
# Unsuccessful, Elapsed Time: 333.993ms
# Solution:
# (0,2)
# (1,7)
# (2,3)
# (3,6)
# (4,0)
# (5,5)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 2.514ms
#
# Unsuccessful, Elapsed Time: 343.475ms
# Unsuccessful, Elapsed Time: 299.947ms
# Unsuccessful, Elapsed Time: 322.496ms
# Unsuccessful, Elapsed Time: 358.937ms
# Unsuccessful, Elapsed Time: 367.543ms
# Unsuccessful, Elapsed Time: 329.145ms
# Unsuccessful, Elapsed Time: 373.54ms
# Solution:
# (0,2)
# (1,5)
# (2,1)
# (3,4)
# (4,7)
# (5,0)
# (6,6)
# (7,3)
#
# Success , Elapsed Time: 1.525ms
#
# Settings		Average Time to Convergence	Success Rate
# Setting 1		14.824ms			13.00%
# Setting 2		22.910ms			7.00%
# Setting 3		5.300ms			16.00%

# %% [markdown]
# ## N = 1000

# %%
param_settings = [
    {'T': 4000, 'epochs': 10000, 'decay': 0.9},  # Setting I
    {'T': 2000, 'epochs': 10000, 'decay': 0.9},  # Setting II
    {'T': 1000, 'epochs': 10000, 'decay': 0.9}   # Setting III
]

performance_table = []

itera = 1000

for setting in param_settings:
    total_time = 0
    success_count = 0

    for _ in range(itera):
        board = Board()
        sa = SimulatedAnnealing(board, setting)
        elapsed_time = sa.run()

        if sa.board.calculateCost() == 0:
            total_time += elapsed_time
            success_count += 1
    if success_count != 0:
        avg_time = total_time / success_count
    else:
        avg_time = 0
    success_rate = success_count / itera

    performance_table.append((avg_time, success_rate))

# Print the performance table
print("Settings\t\tAverage Time to Convergence\tSuccess Rate")
for i, setting in enumerate(param_settings):
    avg_time, success_rate = performance_table[i]
    print(f"Setting {i+1}\t\t{avg_time:.3f}ms\t\t\t{success_rate * 100:.2f}%")
# Out:
# Unsuccessful, Elapsed Time: 376.999ms
# Unsuccessful, Elapsed Time: 357.767ms
# Unsuccessful, Elapsed Time: 376.423ms
# Unsuccessful, Elapsed Time: 307.788ms
# Unsuccessful, Elapsed Time: 288.903ms
# Unsuccessful, Elapsed Time: 331.702ms
# Unsuccessful, Elapsed Time: 366.499ms
# Unsuccessful, Elapsed Time: 307.767ms
# Unsuccessful, Elapsed Time: 369.36ms
# Unsuccessful, Elapsed Time: 310.139ms
# Unsuccessful, Elapsed Time: 373.651ms
# Unsuccessful, Elapsed Time: 355.959ms
# Unsuccessful, Elapsed Time: 349.665ms
# Unsuccessful, Elapsed Time: 323.354ms
# Solution:
# (0,4)
# (1,6)
# (2,0)
# (3,3)
# (4,1)
# (5,7)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 1.379ms
#
# Unsuccessful, Elapsed Time: 355.986ms
# Unsuccessful, Elapsed Time: 246.014ms
# Unsuccessful, Elapsed Time: 322.656ms
# Unsuccessful, Elapsed Time: 382.401ms
# Unsuccessful, Elapsed Time: 335.554ms
# Unsuccessful, Elapsed Time: 362.775ms
# Unsuccessful, Elapsed Time: 315.495ms
# Unsuccessful, Elapsed Time: 352.116ms
# Unsuccessful, Elapsed Time: 201.175ms
# Unsuccessful, Elapsed Time: 381.1ms
# Unsuccessful, Elapsed Time: 333.266ms
# Unsuccessful, Elapsed Time: 314.203ms
# Unsuccessful, Elapsed Time: 271.353ms
# Solution:
# (0,5)
# (1,3)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,1)
# (7,7)
#
# Success , Elapsed Time: 0.699ms
#
# Unsuccessful, Elapsed Time: 335.155ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,4)
# (5,6)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 1.54ms
#
# Unsuccessful, Elapsed Time: 345.296ms
# Unsuccessful, Elapsed Time: 365.922ms
# Unsuccessful, Elapsed Time: 291.264ms
# Solution:
# (0,4)
# (1,2)
# (2,0)
# (3,5)
# (4,7)
# (5,1)
# (6,3)
# (7,6)
#
# Success , Elapsed Time: 0.555ms
#
# Unsuccessful, Elapsed Time: 371.989ms
# Solution:
# (0,7)
# (1,2)
# (2,0)
# (3,5)
# (4,1)
# (5,4)
# (6,6)
# (7,3)
#
# Success , Elapsed Time: 8.326ms
#
# Unsuccessful, Elapsed Time: 372.895ms
# Solution:
# (0,6)
# (1,2)
# (2,0)
# (3,5)
# (4,7)
# (5,4)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 6.779ms
#
# Unsuccessful, Elapsed Time: 288.554ms
# Unsuccessful, Elapsed Time: 257.464ms
# Solution:
# (0,5)
# (1,1)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,7)
# (7,3)
#
# Success , Elapsed Time: 10.964ms
#
# Unsuccessful, Elapsed Time: 247.213ms
# Solution:
# (0,1)
# (1,6)
# (2,4)
# (3,7)
# (4,0)
# (5,3)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 0.567ms
#
# Unsuccessful, Elapsed Time: 350.401ms
# Unsuccessful, Elapsed Time: 344.663ms
# Unsuccessful, Elapsed Time: 281.388ms
# Unsuccessful, Elapsed Time: 386.375ms
# Unsuccessful, Elapsed Time: 229.172ms
# Solution:
# (0,5)
# (1,2)
# (2,4)
# (3,7)
# (4,0)
# (5,3)
# (6,1)
# (7,6)
#
# Success , Elapsed Time: 0.969ms
#
# Unsuccessful, Elapsed Time: 271.653ms
# Unsuccessful, Elapsed Time: 398.144ms
# Solution:
# (0,5)
# (1,2)
# (2,4)
# (3,7)
# (4,0)
# (5,3)
# (6,1)
# (7,6)
#
# Success , Elapsed Time: 11.476ms
#
# Unsuccessful, Elapsed Time: 310.611ms
# Unsuccessful, Elapsed Time: 326.549ms
# Solution:
# (0,5)
# (1,7)
# (2,1)
# (3,3)
# (4,0)
# (5,6)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 7.08ms
#
# Unsuccessful, Elapsed Time: 438.178ms
# Unsuccessful, Elapsed Time: 336.996ms
# Unsuccessful, Elapsed Time: 331.909ms
# Unsuccessful, Elapsed Time: 405.661ms
# Unsuccessful, Elapsed Time: 320.841ms
# Unsuccessful, Elapsed Time: 353.224ms
# Unsuccessful, Elapsed Time: 284.899ms
# Unsuccessful, Elapsed Time: 408.567ms
# Unsuccessful, Elapsed Time: 332.179ms
# Unsuccessful, Elapsed Time: 309.347ms
# Unsuccessful, Elapsed Time: 377.848ms
# Unsuccessful, Elapsed Time: 368.833ms
# Unsuccessful, Elapsed Time: 321.21ms
# Unsuccessful, Elapsed Time: 374.768ms
# Unsuccessful, Elapsed Time: 258.966ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,1)
# (4,7)
# (5,4)
# (6,0)
# (7,3)
#
# Success , Elapsed Time: 1.376ms
#
# Unsuccessful, Elapsed Time: 380.942ms
# Solution:
# (0,6)
# (1,3)
# (2,1)
# (3,7)
# (4,5)
# (5,0)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 2.911ms
#
# Solution:
# (0,1)
# (1,4)
# (2,6)
# (3,0)
# (4,2)
# (5,7)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 0.968ms
#
# Unsuccessful, Elapsed Time: 356.626ms
# Unsuccessful, Elapsed Time: 343.315ms
# Solution:
# (0,4)
# (1,0)
# (2,7)
# (3,5)
# (4,2)
# (5,6)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 0.981ms
#
# Unsuccessful, Elapsed Time: 311.012ms
# Unsuccessful, Elapsed Time: 375.369ms
# Unsuccessful, Elapsed Time: 390.555ms
# Unsuccessful, Elapsed Time: 350.766ms
# Unsuccessful, Elapsed Time: 305.471ms
# Unsuccessful, Elapsed Time: 385.939ms
# Unsuccessful, Elapsed Time: 345.23ms
# Solution:
# (0,6)
# (1,2)
# (2,0)
# (3,5)
# (4,7)
# (5,4)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 2.426ms
#
# Unsuccessful, Elapsed Time: 273.708ms
# Unsuccessful, Elapsed Time: 377.519ms
# Unsuccessful, Elapsed Time: 363.431ms
# Unsuccessful, Elapsed Time: 356.223ms
# Unsuccessful, Elapsed Time: 372.293ms
# Unsuccessful, Elapsed Time: 349.241ms
# Unsuccessful, Elapsed Time: 322.275ms
# Unsuccessful, Elapsed Time: 323.323ms
# Unsuccessful, Elapsed Time: 321.066ms
# Unsuccessful, Elapsed Time: 373.9ms
# Unsuccessful, Elapsed Time: 378.312ms
# Unsuccessful, Elapsed Time: 355.205ms
# Unsuccessful, Elapsed Time: 377.275ms
# Unsuccessful, Elapsed Time: 340.22ms
# Unsuccessful, Elapsed Time: 365.787ms
# Solution:
# (0,2)
# (1,4)
# (2,1)
# (3,7)
# (4,0)
# (5,6)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 4.905ms
#
# Unsuccessful, Elapsed Time: 377.006ms
# Unsuccessful, Elapsed Time: 209.519ms
# Unsuccessful, Elapsed Time: 249.667ms
# Unsuccessful, Elapsed Time: 347.683ms
# Unsuccessful, Elapsed Time: 384.534ms
# Unsuccessful, Elapsed Time: 344.919ms
# Unsuccessful, Elapsed Time: 377.256ms
# Unsuccessful, Elapsed Time: 291.304ms
# Unsuccessful, Elapsed Time: 313.682ms
# Unsuccessful, Elapsed Time: 220.842ms
# Unsuccessful, Elapsed Time: 428.468ms
# Unsuccessful, Elapsed Time: 348.348ms
# Unsuccessful, Elapsed Time: 354.166ms
# Unsuccessful, Elapsed Time: 400.006ms
# Unsuccessful, Elapsed Time: 483.771ms
# Solution:
# (0,1)
# (1,5)
# (2,0)
# (3,6)
# (4,3)
# (5,7)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 1.782ms
#
# Unsuccessful, Elapsed Time: 339.297ms
# Unsuccessful, Elapsed Time: 357.389ms
# Unsuccessful, Elapsed Time: 398.86ms
# Unsuccessful, Elapsed Time: 396.625ms
# Unsuccessful, Elapsed Time: 361.383ms
# Solution:
# (0,2)
# (1,5)
# (2,1)
# (3,6)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 138.797ms
#
# Solution:
# (0,3)
# (1,1)
# (2,7)
# (3,5)
# (4,0)
# (5,2)
# (6,4)
# (7,6)
#
# Success , Elapsed Time: 24.227ms
#
# Unsuccessful, Elapsed Time: 301.212ms
# Unsuccessful, Elapsed Time: 406.401ms
# Unsuccessful, Elapsed Time: 346.892ms
# Unsuccessful, Elapsed Time: 297.108ms
# Unsuccessful, Elapsed Time: 387.887ms
# Unsuccessful, Elapsed Time: 317.093ms
# Unsuccessful, Elapsed Time: 322.135ms
# Unsuccessful, Elapsed Time: 360.854ms
# Unsuccessful, Elapsed Time: 357.542ms
# Unsuccessful, Elapsed Time: 313.909ms
# Unsuccessful, Elapsed Time: 319.044ms
# Unsuccessful, Elapsed Time: 288.147ms
# Unsuccessful, Elapsed Time: 385.932ms
# Unsuccessful, Elapsed Time: 369.031ms
# Unsuccessful, Elapsed Time: 349.077ms
# Unsuccessful, Elapsed Time: 402.143ms
# Unsuccessful, Elapsed Time: 380.015ms
# Unsuccessful, Elapsed Time: 387.337ms
# Solution:
# (0,3)
# (1,1)
# (2,6)
# (3,4)
# (4,0)
# (5,7)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 7.272ms
#
# Unsuccessful, Elapsed Time: 380.498ms
# Unsuccessful, Elapsed Time: 358.069ms
# Unsuccessful, Elapsed Time: 303.236ms
# Unsuccessful, Elapsed Time: 338.166ms
# Solution:
# (0,4)
# (1,6)
# (2,1)
# (3,5)
# (4,2)
# (5,0)
# (6,3)
# (7,7)
#
# Success , Elapsed Time: 25.118ms
#
# Unsuccessful, Elapsed Time: 317.12ms
# Solution:
# (0,4)
# (1,2)
# (2,7)
# (3,3)
# (4,6)
# (5,0)
# (6,5)
# (7,1)
#
# Success , Elapsed Time: 11.67ms
#
# Unsuccessful, Elapsed Time: 353.283ms
# Unsuccessful, Elapsed Time: 403.461ms
# Unsuccessful, Elapsed Time: 418.247ms
# Unsuccessful, Elapsed Time: 474.566ms
# Unsuccessful, Elapsed Time: 377.332ms
# Unsuccessful, Elapsed Time: 364.857ms
# Unsuccessful, Elapsed Time: 408.032ms
# Solution:
# (0,2)
# (1,5)
# (2,1)
# (3,4)
# (4,7)
# (5,0)
# (6,6)
# (7,3)
#
# Success , Elapsed Time: 0.99ms
#
# Unsuccessful, Elapsed Time: 345.059ms
# Unsuccessful, Elapsed Time: 384.538ms
# Unsuccessful, Elapsed Time: 359.194ms
# Unsuccessful, Elapsed Time: 354.387ms
# Unsuccessful, Elapsed Time: 315.155ms
# Unsuccessful, Elapsed Time: 363.397ms
# Unsuccessful, Elapsed Time: 315.398ms
# Unsuccessful, Elapsed Time: 341.641ms
# Solution:
# (0,6)
# (1,3)
# (2,1)
# (3,7)
# (4,5)
# (5,0)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 4.186ms
#
# Unsuccessful, Elapsed Time: 348.244ms
# Unsuccessful, Elapsed Time: 376.602ms
# Unsuccessful, Elapsed Time: 385.518ms
# Unsuccessful, Elapsed Time: 360.218ms
# Solution:
# (0,4)
# (1,0)
# (2,7)
# (3,3)
# (4,1)
# (5,6)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 4.271ms
#
# Unsuccessful, Elapsed Time: 275.512ms
# Unsuccessful, Elapsed Time: 348.136ms
# Unsuccessful, Elapsed Time: 368.238ms
# Unsuccessful, Elapsed Time: 355.511ms
# Unsuccessful, Elapsed Time: 304.103ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,1)
# (4,3)
# (5,7)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 0.811ms
#
# Unsuccessful, Elapsed Time: 322.406ms
# Unsuccessful, Elapsed Time: 337.651ms
# Unsuccessful, Elapsed Time: 361.48ms
# Unsuccessful, Elapsed Time: 360.272ms
# Unsuccessful, Elapsed Time: 342.586ms
# Unsuccessful, Elapsed Time: 265.156ms
# Unsuccessful, Elapsed Time: 354.119ms
# Unsuccessful, Elapsed Time: 295.154ms
# Solution:
# (0,5)
# (1,3)
# (2,0)
# (3,4)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 5.179ms
#
# Unsuccessful, Elapsed Time: 347.828ms
# Unsuccessful, Elapsed Time: 355.155ms
# Unsuccessful, Elapsed Time: 345.444ms
# Unsuccessful, Elapsed Time: 325.074ms
# Solution:
# (0,6)
# (1,1)
# (2,5)
# (3,2)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 16.981ms
#
# Solution:
# (0,5)
# (1,3)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,1)
# (7,7)
#
# Success , Elapsed Time: 49.631ms
#
# Unsuccessful, Elapsed Time: 364.358ms
# Unsuccessful, Elapsed Time: 310.186ms
# Unsuccessful, Elapsed Time: 335.396ms
# Unsuccessful, Elapsed Time: 335.915ms
# Solution:
# (0,0)
# (1,5)
# (2,7)
# (3,2)
# (4,6)
# (5,3)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 4.546ms
#
# Unsuccessful, Elapsed Time: 336.376ms
# Unsuccessful, Elapsed Time: 421.559ms
# Unsuccessful, Elapsed Time: 330.055ms
# Unsuccessful, Elapsed Time: 390.828ms
# Unsuccessful, Elapsed Time: 373.973ms
# Unsuccessful, Elapsed Time: 373.937ms
# Unsuccessful, Elapsed Time: 372.267ms
# Unsuccessful, Elapsed Time: 331.598ms
# Unsuccessful, Elapsed Time: 389.371ms
# Unsuccessful, Elapsed Time: 343.31ms
# Unsuccessful, Elapsed Time: 368.604ms
# Unsuccessful, Elapsed Time: 358.408ms
# Unsuccessful, Elapsed Time: 366.039ms
# Unsuccessful, Elapsed Time: 334.692ms
# Unsuccessful, Elapsed Time: 313.208ms
# Unsuccessful, Elapsed Time: 235.385ms
# Unsuccessful, Elapsed Time: 387.414ms
# Unsuccessful, Elapsed Time: 378.429ms
# Unsuccessful, Elapsed Time: 259.098ms
# Unsuccessful, Elapsed Time: 372.629ms
# Unsuccessful, Elapsed Time: 392.196ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 0.307ms
#
# Unsuccessful, Elapsed Time: 344.596ms
# Unsuccessful, Elapsed Time: 274.329ms
# Unsuccessful, Elapsed Time: 369.701ms
# Unsuccessful, Elapsed Time: 408.095ms
# Unsuccessful, Elapsed Time: 362.33ms
# Unsuccessful, Elapsed Time: 362.104ms
# Unsuccessful, Elapsed Time: 330.285ms
# Unsuccessful, Elapsed Time: 310.532ms
# Unsuccessful, Elapsed Time: 299.622ms
# Unsuccessful, Elapsed Time: 364.469ms
# Unsuccessful, Elapsed Time: 380.949ms
# Solution:
# (0,2)
# (1,4)
# (2,6)
# (3,0)
# (4,3)
# (5,1)
# (6,7)
# (7,5)
#
# Success , Elapsed Time: 15.662ms
#
# Unsuccessful, Elapsed Time: 364.158ms
# Unsuccessful, Elapsed Time: 278.465ms
# Unsuccessful, Elapsed Time: 340.657ms
# Unsuccessful, Elapsed Time: 377.295ms
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,6)
# (4,4)
# (5,7)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 41.771ms
#
# Unsuccessful, Elapsed Time: 345.469ms
# Unsuccessful, Elapsed Time: 373.352ms
# Unsuccessful, Elapsed Time: 345.015ms
# Unsuccessful, Elapsed Time: 408.259ms
# Unsuccessful, Elapsed Time: 366.321ms
# Unsuccessful, Elapsed Time: 367.799ms
# Unsuccessful, Elapsed Time: 322.305ms
# Unsuccessful, Elapsed Time: 315.861ms
# Unsuccessful, Elapsed Time: 277.484ms
# Unsuccessful, Elapsed Time: 317.38ms
# Unsuccessful, Elapsed Time: 338.223ms
# Unsuccessful, Elapsed Time: 300.938ms
# Solution:
# (0,5)
# (1,2)
# (2,4)
# (3,6)
# (4,0)
# (5,3)
# (6,1)
# (7,7)
#
# Success , Elapsed Time: 1.649ms
#
# Unsuccessful, Elapsed Time: 360.065ms
# Unsuccessful, Elapsed Time: 366.659ms
# Unsuccessful, Elapsed Time: 304.863ms
# Unsuccessful, Elapsed Time: 334.688ms
# Unsuccessful, Elapsed Time: 320.896ms
# Unsuccessful, Elapsed Time: 320.092ms
# Unsuccessful, Elapsed Time: 310.836ms
# Unsuccessful, Elapsed Time: 367.422ms
# Solution:
# (0,0)
# (1,6)
# (2,3)
# (3,5)
# (4,7)
# (5,1)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 0.423ms
#
# Unsuccessful, Elapsed Time: 326.007ms
# Unsuccessful, Elapsed Time: 359.713ms
# Solution:
# (0,2)
# (1,0)
# (2,6)
# (3,4)
# (4,7)
# (5,1)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 17.258ms
#
# Unsuccessful, Elapsed Time: 326.987ms
# Unsuccessful, Elapsed Time: 341.007ms
# Unsuccessful, Elapsed Time: 331.998ms
# Solution:
# (0,6)
# (1,2)
# (2,0)
# (3,5)
# (4,7)
# (5,4)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 2.245ms
#
# Unsuccessful, Elapsed Time: 394.788ms
# Unsuccessful, Elapsed Time: 417.804ms
# Unsuccessful, Elapsed Time: 306.966ms
# Unsuccessful, Elapsed Time: 359.607ms
# Unsuccessful, Elapsed Time: 357.037ms
# Unsuccessful, Elapsed Time: 391.126ms
# Unsuccessful, Elapsed Time: 273.856ms
# Unsuccessful, Elapsed Time: 342.768ms
# Unsuccessful, Elapsed Time: 385.248ms
# Unsuccessful, Elapsed Time: 345.217ms
# Unsuccessful, Elapsed Time: 295.803ms
# Unsuccessful, Elapsed Time: 386.242ms
# Unsuccessful, Elapsed Time: 358.931ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,4)
# (5,6)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 1.811ms
#
# Unsuccessful, Elapsed Time: 288.841ms
# Unsuccessful, Elapsed Time: 325.956ms
# Unsuccessful, Elapsed Time: 324.111ms
# Unsuccessful, Elapsed Time: 397.257ms
# Unsuccessful, Elapsed Time: 374.644ms
# Unsuccessful, Elapsed Time: 390.374ms
# Unsuccessful, Elapsed Time: 373.678ms
# Unsuccessful, Elapsed Time: 326.071ms
# Unsuccessful, Elapsed Time: 379.28ms
# Unsuccessful, Elapsed Time: 357.674ms
# Unsuccessful, Elapsed Time: 291.597ms
# Unsuccessful, Elapsed Time: 269.277ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,1)
# (4,6)
# (5,0)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 1.276ms
#
# Unsuccessful, Elapsed Time: 403.652ms
# Unsuccessful, Elapsed Time: 451.037ms
# Unsuccessful, Elapsed Time: 387.283ms
# Unsuccessful, Elapsed Time: 377.612ms
# Unsuccessful, Elapsed Time: 353.738ms
# Unsuccessful, Elapsed Time: 323.48ms
# Unsuccessful, Elapsed Time: 389.19ms
# Unsuccessful, Elapsed Time: 374.134ms
# Unsuccessful, Elapsed Time: 337.475ms
# Unsuccessful, Elapsed Time: 403.614ms
# Unsuccessful, Elapsed Time: 329.0ms
# Unsuccessful, Elapsed Time: 393.905ms
# Unsuccessful, Elapsed Time: 285.876ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 2.375ms
#
# Unsuccessful, Elapsed Time: 380.132ms
# Unsuccessful, Elapsed Time: 347.106ms
# Solution:
# (0,5)
# (1,2)
# (2,4)
# (3,6)
# (4,0)
# (5,3)
# (6,1)
# (7,7)
#
# Success , Elapsed Time: 1.501ms
#
# Unsuccessful, Elapsed Time: 345.148ms
# Unsuccessful, Elapsed Time: 309.708ms
# Unsuccessful, Elapsed Time: 359.059ms
# Unsuccessful, Elapsed Time: 326.772ms
# Unsuccessful, Elapsed Time: 381.778ms
# Unsuccessful, Elapsed Time: 372.428ms
# Unsuccessful, Elapsed Time: 356.224ms
# Unsuccessful, Elapsed Time: 350.128ms
# Unsuccessful, Elapsed Time: 292.795ms
# Unsuccessful, Elapsed Time: 302.553ms
# Solution:
# (0,6)
# (1,1)
# (2,5)
# (3,2)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 1.919ms
#
# Solution:
# (0,5)
# (1,1)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,7)
# (7,3)
#
# Success , Elapsed Time: 0.422ms
#
# Unsuccessful, Elapsed Time: 231.538ms
# Unsuccessful, Elapsed Time: 346.588ms
# Unsuccessful, Elapsed Time: 360.462ms
# Unsuccessful, Elapsed Time: 371.459ms
# Unsuccessful, Elapsed Time: 339.44ms
# Unsuccessful, Elapsed Time: 296.026ms
# Unsuccessful, Elapsed Time: 333.269ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,1)
# (4,7)
# (5,4)
# (6,0)
# (7,3)
#
# Success , Elapsed Time: 4.66ms
#
# Unsuccessful, Elapsed Time: 428.058ms
# Unsuccessful, Elapsed Time: 403.094ms
# Unsuccessful, Elapsed Time: 364.196ms
# Unsuccessful, Elapsed Time: 353.154ms
# Solution:
# (0,3)
# (1,6)
# (2,4)
# (3,2)
# (4,0)
# (5,5)
# (6,7)
# (7,1)
#
# Success , Elapsed Time: 7.164ms
#
# Unsuccessful, Elapsed Time: 358.676ms
# Unsuccessful, Elapsed Time: 393.667ms
# Unsuccessful, Elapsed Time: 393.561ms
# Unsuccessful, Elapsed Time: 398.204ms
# Unsuccessful, Elapsed Time: 317.143ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,1)
# (4,3)
# (5,7)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 2.506ms
#
# Solution:
# (0,4)
# (1,2)
# (2,0)
# (3,6)
# (4,1)
# (5,7)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 0.941ms
#
# Unsuccessful, Elapsed Time: 362.199ms
# Unsuccessful, Elapsed Time: 347.919ms
# Unsuccessful, Elapsed Time: 316.369ms
# Solution:
# (0,6)
# (1,2)
# (2,7)
# (3,1)
# (4,4)
# (5,0)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 0.877ms
#
# Unsuccessful, Elapsed Time: 376.739ms
# Solution:
# (0,4)
# (1,1)
# (2,5)
# (3,0)
# (4,6)
# (5,3)
# (6,7)
# (7,2)
#
# Success , Elapsed Time: 0.571ms
#
# Unsuccessful, Elapsed Time: 419.396ms
# Unsuccessful, Elapsed Time: 389.955ms
# Unsuccessful, Elapsed Time: 388.039ms
# Unsuccessful, Elapsed Time: 409.279ms
# Unsuccessful, Elapsed Time: 324.612ms
# Unsuccessful, Elapsed Time: 361.139ms
# Unsuccessful, Elapsed Time: 351.98ms
# Unsuccessful, Elapsed Time: 365.141ms
# Unsuccessful, Elapsed Time: 283.992ms
# Unsuccessful, Elapsed Time: 314.961ms
# Unsuccessful, Elapsed Time: 399.011ms
# Solution:
# (0,4)
# (1,2)
# (2,7)
# (3,3)
# (4,6)
# (5,0)
# (6,5)
# (7,1)
#
# Success , Elapsed Time: 0.999ms
#
# Unsuccessful, Elapsed Time: 394.966ms
# Unsuccessful, Elapsed Time: 333.334ms
# Unsuccessful, Elapsed Time: 354.774ms
# Unsuccessful, Elapsed Time: 367.309ms
# Unsuccessful, Elapsed Time: 279.947ms
# Unsuccessful, Elapsed Time: 310.387ms
# Solution:
# (0,6)
# (1,4)
# (2,2)
# (3,0)
# (4,5)
# (5,7)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 21.246ms
#
# Unsuccessful, Elapsed Time: 379.59ms
# Solution:
# (0,1)
# (1,3)
# (2,5)
# (3,7)
# (4,2)
# (5,0)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 10.599ms
#
# Unsuccessful, Elapsed Time: 291.544ms
# Unsuccessful, Elapsed Time: 325.76ms
# Solution:
# (0,6)
# (1,3)
# (2,1)
# (3,4)
# (4,7)
# (5,0)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 3.741ms
#
# Unsuccessful, Elapsed Time: 298.46ms
# Unsuccessful, Elapsed Time: 249.426ms
# Unsuccessful, Elapsed Time: 382.084ms
# Unsuccessful, Elapsed Time: 274.296ms
# Unsuccessful, Elapsed Time: 410.587ms
# Unsuccessful, Elapsed Time: 334.45ms
# Unsuccessful, Elapsed Time: 185.0ms
# Unsuccessful, Elapsed Time: 321.823ms
# Unsuccessful, Elapsed Time: 351.948ms
# Unsuccessful, Elapsed Time: 357.35ms
# Unsuccessful, Elapsed Time: 296.282ms
# Unsuccessful, Elapsed Time: 370.102ms
# Unsuccessful, Elapsed Time: 312.516ms
# Unsuccessful, Elapsed Time: 320.913ms
# Unsuccessful, Elapsed Time: 340.268ms
# Unsuccessful, Elapsed Time: 315.422ms
# Unsuccessful, Elapsed Time: 357.037ms
# Unsuccessful, Elapsed Time: 191.915ms
# Unsuccessful, Elapsed Time: 328.917ms
# Unsuccessful, Elapsed Time: 306.75ms
# Unsuccessful, Elapsed Time: 362.61ms
# Unsuccessful, Elapsed Time: 385.149ms
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,7)
# (4,4)
# (5,1)
# (6,3)
# (7,6)
#
# Success , Elapsed Time: 46.946ms
#
# Unsuccessful, Elapsed Time: 270.701ms
# Solution:
# (0,3)
# (1,0)
# (2,4)
# (3,7)
# (4,1)
# (5,6)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 0.286ms
#
# Unsuccessful, Elapsed Time: 260.757ms
# Unsuccessful, Elapsed Time: 357.664ms
# Solution:
# (0,3)
# (1,6)
# (2,4)
# (3,2)
# (4,0)
# (5,5)
# (6,7)
# (7,1)
#
# Success , Elapsed Time: 4.797ms
#
# Unsuccessful, Elapsed Time: 323.115ms
# Unsuccessful, Elapsed Time: 397.014ms
# Unsuccessful, Elapsed Time: 341.107ms
# Unsuccessful, Elapsed Time: 340.847ms
# Unsuccessful, Elapsed Time: 336.047ms
# Unsuccessful, Elapsed Time: 393.709ms
# Unsuccessful, Elapsed Time: 337.865ms
# Unsuccessful, Elapsed Time: 327.981ms
# Unsuccessful, Elapsed Time: 274.564ms
# Unsuccessful, Elapsed Time: 380.482ms
# Unsuccessful, Elapsed Time: 362.305ms
# Unsuccessful, Elapsed Time: 362.342ms
# Unsuccessful, Elapsed Time: 342.586ms
# Unsuccessful, Elapsed Time: 347.017ms
# Unsuccessful, Elapsed Time: 351.754ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,4)
# (5,6)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 20.189ms
#
# Unsuccessful, Elapsed Time: 329.709ms
# Unsuccessful, Elapsed Time: 408.652ms
# Unsuccessful, Elapsed Time: 379.8ms
# Unsuccessful, Elapsed Time: 328.915ms
# Unsuccessful, Elapsed Time: 380.414ms
# Unsuccessful, Elapsed Time: 325.169ms
# Unsuccessful, Elapsed Time: 387.489ms
# Unsuccessful, Elapsed Time: 419.616ms
# Unsuccessful, Elapsed Time: 380.299ms
# Unsuccessful, Elapsed Time: 371.566ms
# Unsuccessful, Elapsed Time: 365.583ms
# Unsuccessful, Elapsed Time: 356.843ms
# Unsuccessful, Elapsed Time: 390.09ms
# Unsuccessful, Elapsed Time: 367.335ms
# Unsuccessful, Elapsed Time: 349.508ms
# Unsuccessful, Elapsed Time: 294.221ms
# Unsuccessful, Elapsed Time: 325.914ms
# Unsuccessful, Elapsed Time: 367.597ms
# Unsuccessful, Elapsed Time: 348.323ms
# Unsuccessful, Elapsed Time: 361.266ms
# Unsuccessful, Elapsed Time: 313.629ms
# Unsuccessful, Elapsed Time: 334.877ms
# Unsuccessful, Elapsed Time: 374.352ms
# Unsuccessful, Elapsed Time: 357.63ms
# Unsuccessful, Elapsed Time: 342.398ms
# Unsuccessful, Elapsed Time: 308.785ms
# Unsuccessful, Elapsed Time: 310.503ms
# Unsuccessful, Elapsed Time: 263.138ms
# Unsuccessful, Elapsed Time: 367.706ms
# Solution:
# (0,1)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,3)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 0.854ms
#
# Unsuccessful, Elapsed Time: 364.383ms
# Unsuccessful, Elapsed Time: 337.001ms
# Unsuccessful, Elapsed Time: 263.656ms
# Unsuccessful, Elapsed Time: 364.207ms
# Unsuccessful, Elapsed Time: 316.0ms
# Unsuccessful, Elapsed Time: 342.667ms
# Unsuccessful, Elapsed Time: 262.581ms
# Solution:
# (0,1)
# (1,4)
# (2,6)
# (3,0)
# (4,2)
# (5,7)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 2.38ms
#
# Unsuccessful, Elapsed Time: 336.143ms
# Unsuccessful, Elapsed Time: 291.888ms
# Unsuccessful, Elapsed Time: 337.556ms
# Unsuccessful, Elapsed Time: 365.007ms
# Unsuccessful, Elapsed Time: 373.756ms
# Unsuccessful, Elapsed Time: 345.823ms
# Unsuccessful, Elapsed Time: 318.398ms
# Unsuccessful, Elapsed Time: 345.226ms
# Solution:
# (0,4)
# (1,7)
# (2,3)
# (3,0)
# (4,6)
# (5,1)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 2.123ms
#
# Unsuccessful, Elapsed Time: 377.755ms
# Unsuccessful, Elapsed Time: 303.608ms
# Solution:
# (0,1)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,3)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 8.163ms
#
# Unsuccessful, Elapsed Time: 308.159ms
# Unsuccessful, Elapsed Time: 333.793ms
# Unsuccessful, Elapsed Time: 372.291ms
# Unsuccessful, Elapsed Time: 317.581ms
# Unsuccessful, Elapsed Time: 359.506ms
# Unsuccessful, Elapsed Time: 384.712ms
# Unsuccessful, Elapsed Time: 304.948ms
# Unsuccessful, Elapsed Time: 344.063ms
# Unsuccessful, Elapsed Time: 412.015ms
# Unsuccessful, Elapsed Time: 313.049ms
# Unsuccessful, Elapsed Time: 332.199ms
# Unsuccessful, Elapsed Time: 310.901ms
# Unsuccessful, Elapsed Time: 316.276ms
# Unsuccessful, Elapsed Time: 383.079ms
# Unsuccessful, Elapsed Time: 309.745ms
# Unsuccessful, Elapsed Time: 390.698ms
# Unsuccessful, Elapsed Time: 307.193ms
# Unsuccessful, Elapsed Time: 315.335ms
# Unsuccessful, Elapsed Time: 322.751ms
# Unsuccessful, Elapsed Time: 287.235ms
# Unsuccessful, Elapsed Time: 336.179ms
# Unsuccessful, Elapsed Time: 387.844ms
# Unsuccessful, Elapsed Time: 374.789ms
# Unsuccessful, Elapsed Time: 445.191ms
# Unsuccessful, Elapsed Time: 277.113ms
# Unsuccessful, Elapsed Time: 326.101ms
# Unsuccessful, Elapsed Time: 326.202ms
# Unsuccessful, Elapsed Time: 335.666ms
# Unsuccessful, Elapsed Time: 351.27ms
# Unsuccessful, Elapsed Time: 343.427ms
# Unsuccessful, Elapsed Time: 375.329ms
# Unsuccessful, Elapsed Time: 339.558ms
# Unsuccessful, Elapsed Time: 341.673ms
# Unsuccessful, Elapsed Time: 308.101ms
# Unsuccessful, Elapsed Time: 311.836ms
# Unsuccessful, Elapsed Time: 348.303ms
# Unsuccessful, Elapsed Time: 351.911ms
# Unsuccessful, Elapsed Time: 403.62ms
# Unsuccessful, Elapsed Time: 344.065ms
# Unsuccessful, Elapsed Time: 286.609ms
# Solution:
# (0,4)
# (1,0)
# (2,7)
# (3,3)
# (4,1)
# (5,6)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 0.417ms
#
# Unsuccessful, Elapsed Time: 365.35ms
# Unsuccessful, Elapsed Time: 352.157ms
# Unsuccessful, Elapsed Time: 330.171ms
# Unsuccessful, Elapsed Time: 379.156ms
# Solution:
# (0,2)
# (1,6)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 11.361ms
#
# Unsuccessful, Elapsed Time: 330.654ms
# Unsuccessful, Elapsed Time: 438.477ms
# Unsuccessful, Elapsed Time: 327.442ms
# Unsuccessful, Elapsed Time: 388.854ms
# Solution:
# (0,4)
# (1,2)
# (2,7)
# (3,3)
# (4,6)
# (5,0)
# (6,5)
# (7,1)
#
# Success , Elapsed Time: 18.476ms
#
# Unsuccessful, Elapsed Time: 355.997ms
# Unsuccessful, Elapsed Time: 385.454ms
# Unsuccessful, Elapsed Time: 326.731ms
# Unsuccessful, Elapsed Time: 325.865ms
# Unsuccessful, Elapsed Time: 238.649ms
# Unsuccessful, Elapsed Time: 357.52ms
# Unsuccessful, Elapsed Time: 264.799ms
# Unsuccessful, Elapsed Time: 344.689ms
# Unsuccessful, Elapsed Time: 375.278ms
# Solution:
# (0,4)
# (1,0)
# (2,7)
# (3,3)
# (4,1)
# (5,6)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 2.454ms
#
# Unsuccessful, Elapsed Time: 351.963ms
# Unsuccessful, Elapsed Time: 382.903ms
# Unsuccessful, Elapsed Time: 307.56ms
# Unsuccessful, Elapsed Time: 340.068ms
# Unsuccessful, Elapsed Time: 313.215ms
# Unsuccessful, Elapsed Time: 309.108ms
# Solution:
# (0,4)
# (1,6)
# (2,1)
# (3,3)
# (4,7)
# (5,0)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 1.95ms
#
# Unsuccessful, Elapsed Time: 396.971ms
# Unsuccessful, Elapsed Time: 374.491ms
# Unsuccessful, Elapsed Time: 318.546ms
# Unsuccessful, Elapsed Time: 306.388ms
# Unsuccessful, Elapsed Time: 317.623ms
# Unsuccessful, Elapsed Time: 387.176ms
# Unsuccessful, Elapsed Time: 330.418ms
# Unsuccessful, Elapsed Time: 349.891ms
# Unsuccessful, Elapsed Time: 372.032ms
# Unsuccessful, Elapsed Time: 339.163ms
# Solution:
# (0,5)
# (1,3)
# (2,1)
# (3,7)
# (4,4)
# (5,6)
# (6,0)
# (7,2)
#
# Success , Elapsed Time: 4.439ms
#
# Solution:
# (0,3)
# (1,1)
# (2,6)
# (3,2)
# (4,5)
# (5,7)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 5.737ms
#
# Unsuccessful, Elapsed Time: 292.869ms
# Unsuccessful, Elapsed Time: 346.494ms
# Solution:
# (0,2)
# (1,4)
# (2,7)
# (3,3)
# (4,0)
# (5,6)
# (6,1)
# (7,5)
#
# Success , Elapsed Time: 1.781ms
#
# Unsuccessful, Elapsed Time: 351.843ms
# Solution:
# (0,4)
# (1,6)
# (2,0)
# (3,2)
# (4,7)
# (5,5)
# (6,3)
# (7,1)
#
# Success , Elapsed Time: 0.557ms
#
# Solution:
# (0,4)
# (1,0)
# (2,3)
# (3,5)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 1.839ms
#
# Unsuccessful, Elapsed Time: 387.877ms
# Unsuccessful, Elapsed Time: 391.705ms
# Unsuccessful, Elapsed Time: 346.633ms
# Solution:
# (0,5)
# (1,3)
# (2,0)
# (3,4)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 31.971ms
#
# Unsuccessful, Elapsed Time: 262.68ms
# Unsuccessful, Elapsed Time: 345.738ms
# Unsuccessful, Elapsed Time: 330.353ms
# Unsuccessful, Elapsed Time: 374.172ms
# Unsuccessful, Elapsed Time: 300.918ms
# Unsuccessful, Elapsed Time: 382.643ms
# Unsuccessful, Elapsed Time: 328.104ms
# Unsuccessful, Elapsed Time: 283.763ms
# Unsuccessful, Elapsed Time: 246.364ms
# Unsuccessful, Elapsed Time: 351.944ms
# Unsuccessful, Elapsed Time: 383.903ms
# Unsuccessful, Elapsed Time: 340.149ms
# Unsuccessful, Elapsed Time: 336.995ms
# Unsuccessful, Elapsed Time: 314.822ms
# Unsuccessful, Elapsed Time: 332.918ms
# Solution:
# (0,2)
# (1,7)
# (2,3)
# (3,6)
# (4,0)
# (5,5)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 7.802ms
#
# Unsuccessful, Elapsed Time: 365.688ms
# Unsuccessful, Elapsed Time: 367.678ms
# Unsuccessful, Elapsed Time: 377.109ms
# Unsuccessful, Elapsed Time: 378.51ms
# Unsuccessful, Elapsed Time: 351.149ms
# Unsuccessful, Elapsed Time: 345.483ms
# Unsuccessful, Elapsed Time: 347.225ms
# Unsuccessful, Elapsed Time: 311.096ms
# Solution:
# (0,3)
# (1,6)
# (2,2)
# (3,7)
# (4,1)
# (5,4)
# (6,0)
# (7,5)
#
# Success , Elapsed Time: 5.643ms
#
# Unsuccessful, Elapsed Time: 291.611ms
# Solution:
# (0,6)
# (1,2)
# (2,7)
# (3,1)
# (4,4)
# (5,0)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 37.061ms
#
# Unsuccessful, Elapsed Time: 346.527ms
# Unsuccessful, Elapsed Time: 256.624ms
# Unsuccessful, Elapsed Time: 363.321ms
# Unsuccessful, Elapsed Time: 291.943ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,1)
# (4,7)
# (5,4)
# (6,0)
# (7,3)
#
# Success , Elapsed Time: 21.243ms
#
# Unsuccessful, Elapsed Time: 377.77ms
# Unsuccessful, Elapsed Time: 328.52ms
# Solution:
# (0,6)
# (1,4)
# (2,2)
# (3,0)
# (4,5)
# (5,7)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 14.431ms
#
# Unsuccessful, Elapsed Time: 395.964ms
# Unsuccessful, Elapsed Time: 273.748ms
# Unsuccessful, Elapsed Time: 346.168ms
# Unsuccessful, Elapsed Time: 310.123ms
# Unsuccessful, Elapsed Time: 408.242ms
# Unsuccessful, Elapsed Time: 296.841ms
# Unsuccessful, Elapsed Time: 373.326ms
# Unsuccessful, Elapsed Time: 347.894ms
# Unsuccessful, Elapsed Time: 381.274ms
# Solution:
# (0,5)
# (1,3)
# (2,1)
# (3,7)
# (4,4)
# (5,6)
# (6,0)
# (7,2)
#
# Success , Elapsed Time: 0.417ms
#
# Unsuccessful, Elapsed Time: 331.876ms
# Unsuccessful, Elapsed Time: 347.319ms
# Unsuccessful, Elapsed Time: 400.496ms
# Solution:
# (0,1)
# (1,6)
# (2,4)
# (3,7)
# (4,0)
# (5,3)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 2.871ms
#
# Unsuccessful, Elapsed Time: 342.981ms
# Unsuccessful, Elapsed Time: 330.094ms
# Unsuccessful, Elapsed Time: 326.032ms
# Solution:
# (0,5)
# (1,3)
# (2,0)
# (3,4)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 12.591ms
#
# Unsuccessful, Elapsed Time: 310.944ms
# Unsuccessful, Elapsed Time: 296.201ms
# Unsuccessful, Elapsed Time: 380.116ms
# Unsuccessful, Elapsed Time: 320.031ms
# Unsuccessful, Elapsed Time: 344.107ms
# Unsuccessful, Elapsed Time: 330.154ms
# Unsuccessful, Elapsed Time: 384.716ms
# Unsuccessful, Elapsed Time: 299.25ms
# Solution:
# (0,2)
# (1,7)
# (2,3)
# (3,6)
# (4,0)
# (5,5)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 6.02ms
#
# Unsuccessful, Elapsed Time: 332.599ms
# Unsuccessful, Elapsed Time: 359.295ms
# Unsuccessful, Elapsed Time: 340.82ms
# Unsuccessful, Elapsed Time: 323.603ms
# Unsuccessful, Elapsed Time: 277.903ms
# Unsuccessful, Elapsed Time: 342.945ms
# Solution:
# (0,0)
# (1,6)
# (2,3)
# (3,5)
# (4,7)
# (5,1)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 0.683ms
#
# Unsuccessful, Elapsed Time: 351.306ms
# Unsuccessful, Elapsed Time: 286.347ms
# Unsuccessful, Elapsed Time: 289.679ms
# Solution:
# (0,5)
# (1,2)
# (2,6)
# (3,3)
# (4,0)
# (5,7)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 2.338ms
#
# Unsuccessful, Elapsed Time: 406.181ms
# Unsuccessful, Elapsed Time: 325.653ms
# Unsuccessful, Elapsed Time: 307.83ms
# Unsuccessful, Elapsed Time: 349.749ms
# Unsuccessful, Elapsed Time: 317.509ms
# Unsuccessful, Elapsed Time: 365.04ms
# Unsuccessful, Elapsed Time: 360.916ms
# Unsuccessful, Elapsed Time: 323.631ms
# Unsuccessful, Elapsed Time: 393.053ms
# Unsuccessful, Elapsed Time: 331.068ms
# Unsuccessful, Elapsed Time: 379.352ms
# Unsuccessful, Elapsed Time: 312.711ms
# Unsuccessful, Elapsed Time: 357.124ms
# Unsuccessful, Elapsed Time: 312.53ms
# Unsuccessful, Elapsed Time: 384.094ms
# Unsuccessful, Elapsed Time: 365.779ms
# Unsuccessful, Elapsed Time: 390.477ms
# Unsuccessful, Elapsed Time: 412.059ms
# Unsuccessful, Elapsed Time: 276.496ms
# Unsuccessful, Elapsed Time: 353.529ms
# Unsuccessful, Elapsed Time: 346.79ms
# Unsuccessful, Elapsed Time: 365.841ms
# Solution:
# (0,6)
# (1,3)
# (2,1)
# (3,4)
# (4,7)
# (5,0)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 8.905ms
#
# Unsuccessful, Elapsed Time: 348.14ms
# Unsuccessful, Elapsed Time: 366.685ms
# Unsuccessful, Elapsed Time: 335.273ms
# Unsuccessful, Elapsed Time: 373.473ms
# Unsuccessful, Elapsed Time: 334.178ms
# Unsuccessful, Elapsed Time: 362.035ms
# Unsuccessful, Elapsed Time: 302.21ms
# Unsuccessful, Elapsed Time: 322.454ms
# Unsuccessful, Elapsed Time: 367.082ms
# Unsuccessful, Elapsed Time: 336.858ms
# Solution:
# (0,2)
# (1,5)
# (2,1)
# (3,6)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 3.436ms
#
# Unsuccessful, Elapsed Time: 367.756ms
# Unsuccessful, Elapsed Time: 356.575ms
# Solution:
# (0,5)
# (1,3)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,1)
# (7,7)
#
# Success , Elapsed Time: 0.823ms
#
# Unsuccessful, Elapsed Time: 338.28ms
# Unsuccessful, Elapsed Time: 376.122ms
# Unsuccessful, Elapsed Time: 358.858ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,1)
# (4,6)
# (5,0)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 14.174ms
#
# Unsuccessful, Elapsed Time: 331.642ms
# Unsuccessful, Elapsed Time: 354.468ms
# Unsuccessful, Elapsed Time: 359.71ms
# Unsuccessful, Elapsed Time: 317.357ms
# Solution:
# (0,4)
# (1,6)
# (2,0)
# (3,2)
# (4,7)
# (5,5)
# (6,3)
# (7,1)
#
# Success , Elapsed Time: 1.66ms
#
# Unsuccessful, Elapsed Time: 301.478ms
# Unsuccessful, Elapsed Time: 312.74ms
# Solution:
# (0,2)
# (1,7)
# (2,3)
# (3,6)
# (4,0)
# (5,5)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 2.76ms
#
# Unsuccessful, Elapsed Time: 339.409ms
# Unsuccessful, Elapsed Time: 268.976ms
# Unsuccessful, Elapsed Time: 373.45ms
# Unsuccessful, Elapsed Time: 299.044ms
# Unsuccessful, Elapsed Time: 308.731ms
# Unsuccessful, Elapsed Time: 335.261ms
# Unsuccessful, Elapsed Time: 379.848ms
# Solution:
# (0,2)
# (1,4)
# (2,1)
# (3,7)
# (4,0)
# (5,6)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 8.997ms
#
# Unsuccessful, Elapsed Time: 316.04ms
# Unsuccessful, Elapsed Time: 343.458ms
# Unsuccessful, Elapsed Time: 365.013ms
# Solution:
# (0,2)
# (1,5)
# (2,1)
# (3,6)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 12.025ms
#
# Solution:
# (0,6)
# (1,4)
# (2,2)
# (3,0)
# (4,5)
# (5,7)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 2.334ms
#
# Unsuccessful, Elapsed Time: 365.822ms
# Unsuccessful, Elapsed Time: 257.943ms
# Unsuccessful, Elapsed Time: 345.611ms
# Unsuccessful, Elapsed Time: 337.451ms
# Unsuccessful, Elapsed Time: 394.854ms
# Unsuccessful, Elapsed Time: 360.951ms
# Unsuccessful, Elapsed Time: 362.492ms
# Solution:
# (0,7)
# (1,1)
# (2,4)
# (3,2)
# (4,0)
# (5,6)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 3.22ms
#
# Unsuccessful, Elapsed Time: 303.685ms
# Unsuccessful, Elapsed Time: 351.963ms
# Unsuccessful, Elapsed Time: 372.217ms
# Unsuccessful, Elapsed Time: 259.778ms
# Unsuccessful, Elapsed Time: 331.603ms
# Solution:
# (0,1)
# (1,3)
# (2,5)
# (3,7)
# (4,2)
# (5,0)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 14.763ms
#
# Unsuccessful, Elapsed Time: 348.948ms
# Solution:
# (0,4)
# (1,2)
# (2,0)
# (3,5)
# (4,7)
# (5,1)
# (6,3)
# (7,6)
#
# Success , Elapsed Time: 14.112ms
#
# Unsuccessful, Elapsed Time: 372.647ms
# Unsuccessful, Elapsed Time: 387.561ms
# Unsuccessful, Elapsed Time: 358.574ms
# Unsuccessful, Elapsed Time: 346.67ms
# Unsuccessful, Elapsed Time: 325.712ms
# Unsuccessful, Elapsed Time: 410.947ms
# Solution:
# (0,3)
# (1,7)
# (2,0)
# (3,4)
# (4,6)
# (5,1)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 23.55ms
#
# Unsuccessful, Elapsed Time: 392.643ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 16.461ms
#
# Unsuccessful, Elapsed Time: 367.773ms
# Unsuccessful, Elapsed Time: 291.687ms
# Unsuccessful, Elapsed Time: 400.907ms
# Unsuccessful, Elapsed Time: 387.614ms
# Unsuccessful, Elapsed Time: 308.146ms
# Unsuccessful, Elapsed Time: 284.494ms
# Solution:
# (0,4)
# (1,6)
# (2,3)
# (3,0)
# (4,2)
# (5,7)
# (6,5)
# (7,1)
#
# Success , Elapsed Time: 2.533ms
#
# Unsuccessful, Elapsed Time: 346.013ms
# Unsuccessful, Elapsed Time: 356.903ms
# Unsuccessful, Elapsed Time: 345.253ms
# Unsuccessful, Elapsed Time: 316.532ms
# Unsuccessful, Elapsed Time: 348.772ms
# Unsuccessful, Elapsed Time: 248.784ms
# Solution:
# (0,0)
# (1,6)
# (2,3)
# (3,5)
# (4,7)
# (5,1)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 0.813ms
#
# Unsuccessful, Elapsed Time: 406.743ms
# Unsuccessful, Elapsed Time: 364.519ms
# Unsuccessful, Elapsed Time: 319.685ms
# Unsuccessful, Elapsed Time: 393.73ms
# Unsuccessful, Elapsed Time: 344.739ms
# Unsuccessful, Elapsed Time: 352.418ms
# Unsuccessful, Elapsed Time: 274.505ms
# Unsuccessful, Elapsed Time: 283.442ms
# Unsuccessful, Elapsed Time: 343.568ms
# Unsuccessful, Elapsed Time: 312.1ms
# Unsuccessful, Elapsed Time: 379.412ms
# Unsuccessful, Elapsed Time: 300.344ms
# Unsuccessful, Elapsed Time: 353.999ms
# Unsuccessful, Elapsed Time: 368.59ms
# Unsuccessful, Elapsed Time: 358.153ms
# Unsuccessful, Elapsed Time: 349.432ms
# Unsuccessful, Elapsed Time: 333.302ms
# Unsuccessful, Elapsed Time: 310.256ms
# Solution:
# (0,3)
# (1,6)
# (2,4)
# (3,2)
# (4,0)
# (5,5)
# (6,7)
# (7,1)
#
# Success , Elapsed Time: 1.372ms
#
# Unsuccessful, Elapsed Time: 339.404ms
# Unsuccessful, Elapsed Time: 334.422ms
# Unsuccessful, Elapsed Time: 291.36ms
# Unsuccessful, Elapsed Time: 332.135ms
# Unsuccessful, Elapsed Time: 346.991ms
# Solution:
# (0,5)
# (1,3)
# (2,6)
# (3,0)
# (4,2)
# (5,4)
# (6,1)
# (7,7)
#
# Success , Elapsed Time: 0.839ms
#
# Unsuccessful, Elapsed Time: 325.471ms
# Unsuccessful, Elapsed Time: 305.593ms
# Unsuccessful, Elapsed Time: 349.102ms
# Unsuccessful, Elapsed Time: 339.179ms
# Solution:
# (0,3)
# (1,1)
# (2,4)
# (3,7)
# (4,5)
# (5,0)
# (6,2)
# (7,6)
#
# Success , Elapsed Time: 7.085ms
#
# Unsuccessful, Elapsed Time: 379.355ms
# Solution:
# (0,3)
# (1,1)
# (2,6)
# (3,2)
# (4,5)
# (5,7)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 9.402ms
#
# Unsuccessful, Elapsed Time: 353.351ms
# Solution:
# (0,6)
# (1,1)
# (2,3)
# (3,0)
# (4,7)
# (5,4)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 17.561ms
#
# Unsuccessful, Elapsed Time: 402.792ms
# Unsuccessful, Elapsed Time: 369.392ms
# Unsuccessful, Elapsed Time: 388.535ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,3)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 1.369ms
#
# Unsuccessful, Elapsed Time: 314.95ms
# Unsuccessful, Elapsed Time: 284.184ms
# Solution:
# (0,4)
# (1,6)
# (2,1)
# (3,3)
# (4,7)
# (5,0)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 5.13ms
#
# Unsuccessful, Elapsed Time: 369.101ms
# Unsuccessful, Elapsed Time: 267.022ms
# Solution:
# (0,6)
# (1,2)
# (2,0)
# (3,5)
# (4,7)
# (5,4)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 2.749ms
#
# Unsuccessful, Elapsed Time: 378.222ms
# Unsuccessful, Elapsed Time: 353.807ms
# Unsuccessful, Elapsed Time: 325.228ms
# Unsuccessful, Elapsed Time: 376.514ms
# Unsuccessful, Elapsed Time: 286.324ms
# Unsuccessful, Elapsed Time: 333.743ms
# Unsuccessful, Elapsed Time: 362.176ms
# Unsuccessful, Elapsed Time: 351.253ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,3)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 5.752ms
#
# Unsuccessful, Elapsed Time: 308.13ms
# Unsuccessful, Elapsed Time: 332.782ms
# Unsuccessful, Elapsed Time: 380.439ms
# Unsuccessful, Elapsed Time: 245.166ms
# Unsuccessful, Elapsed Time: 352.189ms
# Solution:
# (0,2)
# (1,6)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 8.74ms
#
# Unsuccessful, Elapsed Time: 225.373ms
# Solution:
# (0,5)
# (1,3)
# (2,0)
# (3,4)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 1.92ms
#
# Unsuccessful, Elapsed Time: 356.92ms
# Unsuccessful, Elapsed Time: 348.706ms
# Unsuccessful, Elapsed Time: 259.142ms
# Unsuccessful, Elapsed Time: 357.326ms
# Unsuccessful, Elapsed Time: 372.39ms
# Unsuccessful, Elapsed Time: 303.236ms
# Unsuccessful, Elapsed Time: 349.389ms
# Solution:
# (0,3)
# (1,5)
# (2,0)
# (3,4)
# (4,1)
# (5,7)
# (6,2)
# (7,6)
#
# Success , Elapsed Time: 93.685ms
#
# Unsuccessful, Elapsed Time: 344.936ms
# Unsuccessful, Elapsed Time: 333.975ms
# Unsuccessful, Elapsed Time: 319.27ms
# Unsuccessful, Elapsed Time: 364.527ms
# Unsuccessful, Elapsed Time: 330.132ms
# Unsuccessful, Elapsed Time: 370.013ms
# Unsuccessful, Elapsed Time: 349.768ms
# Unsuccessful, Elapsed Time: 315.726ms
# Unsuccessful, Elapsed Time: 245.137ms
# Unsuccessful, Elapsed Time: 323.456ms
# Solution:
# (0,2)
# (1,7)
# (2,3)
# (3,6)
# (4,0)
# (5,5)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 0.415ms
#
# Unsuccessful, Elapsed Time: 359.269ms
# Unsuccessful, Elapsed Time: 330.792ms
# Unsuccessful, Elapsed Time: 349.936ms
# Unsuccessful, Elapsed Time: 305.682ms
# Unsuccessful, Elapsed Time: 288.549ms
# Unsuccessful, Elapsed Time: 294.821ms
# Solution:
# (0,2)
# (1,5)
# (2,1)
# (3,6)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 12.607ms
#
# Unsuccessful, Elapsed Time: 285.056ms
# Unsuccessful, Elapsed Time: 359.762ms
# Unsuccessful, Elapsed Time: 346.967ms
# Unsuccessful, Elapsed Time: 286.401ms
# Solution:
# (0,3)
# (1,1)
# (2,6)
# (3,2)
# (4,5)
# (5,7)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 0.959ms
#
# Unsuccessful, Elapsed Time: 336.048ms
# Unsuccessful, Elapsed Time: 358.897ms
# Unsuccessful, Elapsed Time: 334.714ms
# Unsuccessful, Elapsed Time: 304.237ms
# Unsuccessful, Elapsed Time: 355.239ms
# Unsuccessful, Elapsed Time: 389.231ms
# Unsuccessful, Elapsed Time: 338.716ms
# Unsuccessful, Elapsed Time: 312.239ms
# Unsuccessful, Elapsed Time: 329.727ms
# Unsuccessful, Elapsed Time: 304.688ms
# Unsuccessful, Elapsed Time: 351.552ms
# Unsuccessful, Elapsed Time: 328.558ms
# Unsuccessful, Elapsed Time: 392.938ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 0.415ms
#
# Unsuccessful, Elapsed Time: 351.435ms
# Unsuccessful, Elapsed Time: 388.74ms
# Unsuccessful, Elapsed Time: 276.113ms
# Unsuccessful, Elapsed Time: 394.61ms
# Unsuccessful, Elapsed Time: 298.325ms
# Unsuccessful, Elapsed Time: 323.035ms
# Unsuccessful, Elapsed Time: 303.282ms
# Unsuccessful, Elapsed Time: 319.895ms
# Unsuccessful, Elapsed Time: 277.207ms
# Unsuccessful, Elapsed Time: 281.535ms
# Unsuccessful, Elapsed Time: 369.013ms
# Unsuccessful, Elapsed Time: 291.465ms
# Solution:
# (0,4)
# (1,1)
# (2,7)
# (3,0)
# (4,3)
# (5,6)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 7.07ms
#
# Unsuccessful, Elapsed Time: 449.371ms
# Solution:
# (0,4)
# (1,0)
# (2,3)
# (3,5)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 0.426ms
#
# Unsuccessful, Elapsed Time: 366.534ms
# Unsuccessful, Elapsed Time: 261.639ms
# Unsuccessful, Elapsed Time: 340.866ms
# Solution:
# (0,3)
# (1,1)
# (2,6)
# (3,4)
# (4,0)
# (5,7)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 8.296ms
#
# Unsuccessful, Elapsed Time: 360.871ms
# Solution:
# (0,4)
# (1,7)
# (2,3)
# (3,0)
# (4,2)
# (5,5)
# (6,1)
# (7,6)
#
# Success , Elapsed Time: 15.098ms
#
# Unsuccessful, Elapsed Time: 347.101ms
# Unsuccessful, Elapsed Time: 285.083ms
# Unsuccessful, Elapsed Time: 342.11ms
# Unsuccessful, Elapsed Time: 386.047ms
# Unsuccessful, Elapsed Time: 353.471ms
# Solution:
# (0,5)
# (1,7)
# (2,1)
# (3,3)
# (4,0)
# (5,6)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 3.971ms
#
# Unsuccessful, Elapsed Time: 378.153ms
# Unsuccessful, Elapsed Time: 362.441ms
# Unsuccessful, Elapsed Time: 356.609ms
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,7)
# (4,4)
# (5,1)
# (6,3)
# (7,6)
#
# Success , Elapsed Time: 1.665ms
#
# Unsuccessful, Elapsed Time: 360.786ms
# Unsuccessful, Elapsed Time: 280.088ms
# Unsuccessful, Elapsed Time: 389.78ms
# Unsuccessful, Elapsed Time: 291.551ms
# Unsuccessful, Elapsed Time: 291.248ms
# Unsuccessful, Elapsed Time: 403.329ms
# Unsuccessful, Elapsed Time: 333.958ms
# Unsuccessful, Elapsed Time: 332.484ms
# Unsuccessful, Elapsed Time: 364.699ms
# Unsuccessful, Elapsed Time: 375.755ms
# Unsuccessful, Elapsed Time: 270.394ms
# Unsuccessful, Elapsed Time: 378.643ms
# Unsuccessful, Elapsed Time: 322.66ms
# Solution:
# (0,5)
# (1,0)
# (2,4)
# (3,1)
# (4,7)
# (5,2)
# (6,6)
# (7,3)
#
# Success , Elapsed Time: 4.998ms
#
# Unsuccessful, Elapsed Time: 325.603ms
# Unsuccessful, Elapsed Time: 386.683ms
# Unsuccessful, Elapsed Time: 344.336ms
# Unsuccessful, Elapsed Time: 409.628ms
# Unsuccessful, Elapsed Time: 387.346ms
# Unsuccessful, Elapsed Time: 379.003ms
# Unsuccessful, Elapsed Time: 318.715ms
# Solution:
# (0,5)
# (1,3)
# (2,0)
# (3,4)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 12.013ms
#
# Unsuccessful, Elapsed Time: 313.983ms
# Unsuccessful, Elapsed Time: 378.007ms
# Unsuccessful, Elapsed Time: 356.552ms
# Unsuccessful, Elapsed Time: 343.601ms
# Unsuccessful, Elapsed Time: 277.5ms
# Unsuccessful, Elapsed Time: 334.473ms
# Unsuccessful, Elapsed Time: 276.688ms
# Unsuccessful, Elapsed Time: 308.413ms
# Unsuccessful, Elapsed Time: 373.148ms
# Unsuccessful, Elapsed Time: 257.678ms
# Solution:
# (0,5)
# (1,3)
# (2,0)
# (3,4)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 48.48ms
#
# Unsuccessful, Elapsed Time: 392.823ms
# Unsuccessful, Elapsed Time: 323.494ms
# Unsuccessful, Elapsed Time: 388.313ms
# Unsuccessful, Elapsed Time: 413.346ms
# Unsuccessful, Elapsed Time: 344.144ms
# Unsuccessful, Elapsed Time: 404.857ms
# Unsuccessful, Elapsed Time: 422.552ms
# Solution:
# (0,2)
# (1,4)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,6)
# (7,0)
#
# Success , Elapsed Time: 0.588ms
#
# Unsuccessful, Elapsed Time: 401.147ms
# Unsuccessful, Elapsed Time: 387.06ms
# Unsuccessful, Elapsed Time: 390.097ms
# Unsuccessful, Elapsed Time: 279.832ms
# Unsuccessful, Elapsed Time: 295.428ms
# Unsuccessful, Elapsed Time: 443.227ms
# Unsuccessful, Elapsed Time: 494.94ms
# Unsuccessful, Elapsed Time: 334.174ms
# Unsuccessful, Elapsed Time: 373.346ms
# Unsuccessful, Elapsed Time: 398.722ms
# Unsuccessful, Elapsed Time: 353.445ms
# Unsuccessful, Elapsed Time: 375.258ms
# Unsuccessful, Elapsed Time: 371.374ms
# Unsuccessful, Elapsed Time: 340.876ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,3)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 18.722ms
#
# Unsuccessful, Elapsed Time: 431.566ms
# Unsuccessful, Elapsed Time: 355.099ms
# Unsuccessful, Elapsed Time: 311.937ms
# Unsuccessful, Elapsed Time: 386.87ms
# Unsuccessful, Elapsed Time: 372.712ms
# Unsuccessful, Elapsed Time: 297.628ms
# Solution:
# (0,1)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,3)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 1.012ms
#
# Unsuccessful, Elapsed Time: 361.458ms
# Unsuccessful, Elapsed Time: 375.693ms
# Unsuccessful, Elapsed Time: 368.081ms
# Unsuccessful, Elapsed Time: 339.937ms
# Unsuccessful, Elapsed Time: 184.011ms
# Solution:
# (0,6)
# (1,4)
# (2,2)
# (3,0)
# (4,5)
# (5,7)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 3.62ms
#
# Unsuccessful, Elapsed Time: 375.759ms
# Solution:
# (0,6)
# (1,1)
# (2,5)
# (3,2)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 11.681ms
#
# Solution:
# (0,0)
# (1,5)
# (2,7)
# (3,2)
# (4,6)
# (5,3)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 0.404ms
#
# Unsuccessful, Elapsed Time: 358.685ms
# Unsuccessful, Elapsed Time: 392.632ms
# Unsuccessful, Elapsed Time: 338.28ms
# Unsuccessful, Elapsed Time: 382.994ms
# Unsuccessful, Elapsed Time: 325.942ms
# Unsuccessful, Elapsed Time: 344.068ms
# Solution:
# (0,6)
# (1,2)
# (2,7)
# (3,1)
# (4,4)
# (5,0)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 18.071ms
#
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,1)
# (4,3)
# (5,0)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 1.665ms
#
# Unsuccessful, Elapsed Time: 325.09ms
# Unsuccessful, Elapsed Time: 384.122ms
# Unsuccessful, Elapsed Time: 365.488ms
# Solution:
# (0,4)
# (1,6)
# (2,3)
# (3,0)
# (4,2)
# (5,7)
# (6,5)
# (7,1)
#
# Success , Elapsed Time: 20.089ms
#
# Unsuccessful, Elapsed Time: 412.176ms
# Unsuccessful, Elapsed Time: 345.951ms
# Unsuccessful, Elapsed Time: 318.599ms
# Solution:
# (0,4)
# (1,0)
# (2,7)
# (3,5)
# (4,2)
# (5,6)
# (6,1)
# (7,3)
#
# Success , Elapsed Time: 0.828ms
#
# Unsuccessful, Elapsed Time: 285.594ms
# Unsuccessful, Elapsed Time: 348.039ms
# Unsuccessful, Elapsed Time: 376.748ms
# Unsuccessful, Elapsed Time: 321.962ms
# Unsuccessful, Elapsed Time: 344.48ms
# Unsuccessful, Elapsed Time: 385.183ms
# Unsuccessful, Elapsed Time: 277.695ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,1)
# (4,3)
# (5,0)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 1.668ms
#
# Unsuccessful, Elapsed Time: 279.757ms
# Unsuccessful, Elapsed Time: 364.117ms
# Unsuccessful, Elapsed Time: 399.622ms
# Unsuccessful, Elapsed Time: 349.309ms
# Unsuccessful, Elapsed Time: 331.828ms
# Unsuccessful, Elapsed Time: 311.886ms
# Unsuccessful, Elapsed Time: 310.537ms
# Solution:
# (0,4)
# (1,6)
# (2,0)
# (3,2)
# (4,7)
# (5,5)
# (6,3)
# (7,1)
#
# Success , Elapsed Time: 1.648ms
#
# Unsuccessful, Elapsed Time: 232.534ms
# Unsuccessful, Elapsed Time: 351.028ms
# Unsuccessful, Elapsed Time: 341.502ms
# Unsuccessful, Elapsed Time: 388.953ms
# Unsuccessful, Elapsed Time: 378.376ms
# Unsuccessful, Elapsed Time: 347.319ms
# Unsuccessful, Elapsed Time: 377.271ms
# Solution:
# (0,2)
# (1,5)
# (2,1)
# (3,6)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 1.667ms
#
# Unsuccessful, Elapsed Time: 304.162ms
# Unsuccessful, Elapsed Time: 327.23ms
# Unsuccessful, Elapsed Time: 347.811ms
# Unsuccessful, Elapsed Time: 327.072ms
# Unsuccessful, Elapsed Time: 373.64ms
# Unsuccessful, Elapsed Time: 324.073ms
# Unsuccessful, Elapsed Time: 326.424ms
# Unsuccessful, Elapsed Time: 315.388ms
# Unsuccessful, Elapsed Time: 353.782ms
# Unsuccessful, Elapsed Time: 375.316ms
# Unsuccessful, Elapsed Time: 344.176ms
# Unsuccessful, Elapsed Time: 350.114ms
# Solution:
# (0,2)
# (1,6)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 7.274ms
#
# Unsuccessful, Elapsed Time: 351.935ms
# Unsuccessful, Elapsed Time: 376.224ms
# Unsuccessful, Elapsed Time: 346.274ms
# Unsuccessful, Elapsed Time: 383.383ms
# Unsuccessful, Elapsed Time: 371.114ms
# Unsuccessful, Elapsed Time: 365.315ms
# Unsuccessful, Elapsed Time: 376.268ms
# Unsuccessful, Elapsed Time: 291.691ms
# Unsuccessful, Elapsed Time: 378.493ms
# Unsuccessful, Elapsed Time: 360.127ms
# Unsuccessful, Elapsed Time: 361.587ms
# Unsuccessful, Elapsed Time: 376.874ms
# Unsuccessful, Elapsed Time: 381.556ms
# Unsuccessful, Elapsed Time: 348.966ms
# Unsuccessful, Elapsed Time: 305.137ms
# Unsuccessful, Elapsed Time: 293.096ms
# Unsuccessful, Elapsed Time: 343.744ms
# Unsuccessful, Elapsed Time: 208.096ms
# Unsuccessful, Elapsed Time: 351.056ms
# Unsuccessful, Elapsed Time: 382.155ms
# Unsuccessful, Elapsed Time: 297.585ms
# Unsuccessful, Elapsed Time: 219.137ms
# Unsuccessful, Elapsed Time: 382.419ms
# Unsuccessful, Elapsed Time: 337.487ms
# Unsuccessful, Elapsed Time: 362.052ms
# Unsuccessful, Elapsed Time: 346.515ms
# Unsuccessful, Elapsed Time: 333.811ms
# Unsuccessful, Elapsed Time: 359.932ms
# Unsuccessful, Elapsed Time: 432.774ms
# Solution:
# (0,6)
# (1,3)
# (2,1)
# (3,4)
# (4,7)
# (5,0)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 0.15ms
#
# Unsuccessful, Elapsed Time: 409.863ms
# Unsuccessful, Elapsed Time: 215.221ms
# Unsuccessful, Elapsed Time: 337.123ms
# Solution:
# (0,5)
# (1,3)
# (2,6)
# (3,0)
# (4,7)
# (5,1)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 25.568ms
#
# Unsuccessful, Elapsed Time: 351.711ms
# Unsuccessful, Elapsed Time: 347.717ms
# Unsuccessful, Elapsed Time: 369.345ms
# Unsuccessful, Elapsed Time: 315.381ms
# Unsuccessful, Elapsed Time: 350.057ms
# Unsuccessful, Elapsed Time: 378.644ms
# Solution:
# (0,2)
# (1,4)
# (2,1)
# (3,7)
# (4,0)
# (5,6)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 1.109ms
#
# Unsuccessful, Elapsed Time: 388.479ms
# Unsuccessful, Elapsed Time: 367.063ms
# Solution:
# (0,2)
# (1,5)
# (2,1)
# (3,6)
# (4,0)
# (5,3)
# (6,7)
# (7,4)
#
# Success , Elapsed Time: 23.006ms
#
# Unsuccessful, Elapsed Time: 349.84ms
# Solution:
# (0,4)
# (1,0)
# (2,3)
# (3,5)
# (4,7)
# (5,1)
# (6,6)
# (7,2)
#
# Success , Elapsed Time: 13.609ms
#
# Unsuccessful, Elapsed Time: 349.17ms
# Unsuccessful, Elapsed Time: 332.809ms
# Unsuccessful, Elapsed Time: 346.371ms
# Unsuccessful, Elapsed Time: 327.597ms
# Unsuccessful, Elapsed Time: 369.466ms
# Unsuccessful, Elapsed Time: 319.039ms
# Unsuccessful, Elapsed Time: 321.413ms
# Unsuccessful, Elapsed Time: 279.876ms
# Solution:
# (0,4)
# (1,7)
# (2,3)
# (3,0)
# (4,6)
# (5,1)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 0.426ms
#
# Unsuccessful, Elapsed Time: 393.654ms
# Solution:
# (0,3)
# (1,7)
# (2,0)
# (3,2)
# (4,5)
# (5,1)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 2.366ms
#
# Unsuccessful, Elapsed Time: 410.311ms
# Unsuccessful, Elapsed Time: 296.436ms
# Unsuccessful, Elapsed Time: 390.296ms
# Unsuccessful, Elapsed Time: 307.747ms
# Solution:
# (0,2)
# (1,6)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 5.597ms
#
# ...
# Unsuccessful, Elapsed Time: 346.664ms
# Unsuccessful, Elapsed Time: 305.538ms
# Unsuccessful, Elapsed Time: 329.819ms
# Unsuccessful, Elapsed Time: 253.476ms
# Unsuccessful, Elapsed Time: 353.253ms
# Unsuccessful, Elapsed Time: 369.637ms
# Unsuccessful, Elapsed Time: 258.263ms
# Unsuccessful, Elapsed Time: 348.435ms
# Unsuccessful, Elapsed Time: 350.753ms
# Unsuccessful, Elapsed Time: 247.621ms
# Unsuccessful, Elapsed Time: 391.226ms
# Solution:
# (0,4)
# (1,6)
# (2,3)
# (3,0)
# (4,2)
# (5,7)
# (6,5)
# (7,1)
#
# Success , Elapsed Time: 3.237ms
#
# Unsuccessful, Elapsed Time: 365.339ms
# Unsuccessful, Elapsed Time: 366.241ms
# Unsuccessful, Elapsed Time: 359.14ms
# Unsuccessful, Elapsed Time: 382.048ms
# Unsuccessful, Elapsed Time: 339.192ms
# Unsuccessful, Elapsed Time: 344.069ms
# Unsuccessful, Elapsed Time: 352.729ms
# Unsuccessful, Elapsed Time: 288.157ms
# Unsuccessful, Elapsed Time: 325.87ms
# Unsuccessful, Elapsed Time: 269.481ms
# Unsuccessful, Elapsed Time: 316.009ms
# Unsuccessful, Elapsed Time: 346.341ms
# Unsuccessful, Elapsed Time: 266.756ms
# Unsuccessful, Elapsed Time: 357.553ms
# Unsuccessful, Elapsed Time: 360.011ms
# Unsuccessful, Elapsed Time: 366.649ms
# Unsuccessful, Elapsed Time: 336.601ms
# Unsuccessful, Elapsed Time: 348.834ms
# Unsuccessful, Elapsed Time: 303.041ms
# Unsuccessful, Elapsed Time: 261.471ms
# Unsuccessful, Elapsed Time: 374.621ms
# Unsuccessful, Elapsed Time: 323.186ms
# Solution:
# (0,3)
# (1,7)
# (2,4)
# (3,2)
# (4,0)
# (5,6)
# (6,1)
# (7,5)
#
# Success , Elapsed Time: 0.833ms
#
# Unsuccessful, Elapsed Time: 306.921ms
# Unsuccessful, Elapsed Time: 365.343ms
# Unsuccessful, Elapsed Time: 343.872ms
# Unsuccessful, Elapsed Time: 309.897ms
# Unsuccessful, Elapsed Time: 323.212ms
# Unsuccessful, Elapsed Time: 371.029ms
# Unsuccessful, Elapsed Time: 398.154ms
# Unsuccessful, Elapsed Time: 351.655ms
# Unsuccessful, Elapsed Time: 314.777ms
# Unsuccessful, Elapsed Time: 318.37ms
# Unsuccessful, Elapsed Time: 368.327ms
# Unsuccessful, Elapsed Time: 317.528ms
# Unsuccessful, Elapsed Time: 321.531ms
# Unsuccessful, Elapsed Time: 396.835ms
# Solution:
# (0,1)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,3)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 7.738ms
#
# Unsuccessful, Elapsed Time: 345.297ms
# Unsuccessful, Elapsed Time: 323.41ms
# Unsuccessful, Elapsed Time: 376.261ms
# Unsuccessful, Elapsed Time: 328.012ms
# Unsuccessful, Elapsed Time: 284.715ms
# Solution:
# (0,1)
# (1,7)
# (2,5)
# (3,0)
# (4,2)
# (5,4)
# (6,6)
# (7,3)
#
# Success , Elapsed Time: 1.789ms
#
# Unsuccessful, Elapsed Time: 351.84ms
# Unsuccessful, Elapsed Time: 318.033ms
# Unsuccessful, Elapsed Time: 369.008ms
# Unsuccessful, Elapsed Time: 386.251ms
# Unsuccessful, Elapsed Time: 316.848ms
# Solution:
# (0,5)
# (1,1)
# (2,6)
# (3,0)
# (4,3)
# (5,7)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 0.695ms
#
# Unsuccessful, Elapsed Time: 317.341ms
# Unsuccessful, Elapsed Time: 352.242ms
# Unsuccessful, Elapsed Time: 243.88ms
# Unsuccessful, Elapsed Time: 362.379ms
# Unsuccessful, Elapsed Time: 253.531ms
# Unsuccessful, Elapsed Time: 331.918ms
# Unsuccessful, Elapsed Time: 333.594ms
# Unsuccessful, Elapsed Time: 294.092ms
# Unsuccessful, Elapsed Time: 426.206ms
# Unsuccessful, Elapsed Time: 359.065ms
# Unsuccessful, Elapsed Time: 373.826ms
# Unsuccessful, Elapsed Time: 383.071ms
# Unsuccessful, Elapsed Time: 338.228ms
# Unsuccessful, Elapsed Time: 356.714ms
# Unsuccessful, Elapsed Time: 368.17ms
# Unsuccessful, Elapsed Time: 368.266ms
# Solution:
# (0,1)
# (1,4)
# (2,6)
# (3,0)
# (4,2)
# (5,7)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 0.411ms
#
# Unsuccessful, Elapsed Time: 264.876ms
# Unsuccessful, Elapsed Time: 346.451ms
# Unsuccessful, Elapsed Time: 328.93ms
# Unsuccessful, Elapsed Time: 329.154ms
# Solution:
# (0,1)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,3)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 0.987ms
#
# Solution:
# (0,2)
# (1,6)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 0.408ms
#
# Unsuccessful, Elapsed Time: 362.6ms
# Unsuccessful, Elapsed Time: 342.681ms
# Unsuccessful, Elapsed Time: 336.16ms
# Unsuccessful, Elapsed Time: 410.499ms
# Unsuccessful, Elapsed Time: 348.076ms
# Solution:
# (0,4)
# (1,7)
# (2,3)
# (3,0)
# (4,6)
# (5,1)
# (6,5)
# (7,2)
#
# Success , Elapsed Time: 3.191ms
#
# Unsuccessful, Elapsed Time: 325.264ms
# Unsuccessful, Elapsed Time: 346.871ms
# Unsuccessful, Elapsed Time: 255.929ms
# Unsuccessful, Elapsed Time: 356.844ms
# Unsuccessful, Elapsed Time: 339.346ms
# Unsuccessful, Elapsed Time: 299.519ms
# Unsuccessful, Elapsed Time: 352.964ms
# Solution:
# (0,3)
# (1,6)
# (2,2)
# (3,7)
# (4,1)
# (5,4)
# (6,0)
# (7,5)
#
# Success , Elapsed Time: 0.992ms
#
# Unsuccessful, Elapsed Time: 377.75ms
# Unsuccessful, Elapsed Time: 349.242ms
# Unsuccessful, Elapsed Time: 388.716ms
# Unsuccessful, Elapsed Time: 381.509ms
# Unsuccessful, Elapsed Time: 349.778ms
# Unsuccessful, Elapsed Time: 317.834ms
# Unsuccessful, Elapsed Time: 379.005ms
# Unsuccessful, Elapsed Time: 354.45ms
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,7)
# (4,3)
# (5,1)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 1.657ms
#
# Unsuccessful, Elapsed Time: 299.572ms
# Unsuccessful, Elapsed Time: 347.799ms
# Solution:
# (0,4)
# (1,1)
# (2,5)
# (3,0)
# (4,6)
# (5,3)
# (6,7)
# (7,2)
#
# Success , Elapsed Time: 15.426ms
#
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,7)
# (4,4)
# (5,1)
# (6,3)
# (7,6)
#
# Success , Elapsed Time: 12.372ms
#
# Unsuccessful, Elapsed Time: 281.862ms
# Solution:
# (0,6)
# (1,1)
# (2,3)
# (3,0)
# (4,7)
# (5,4)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 5.194ms
#
# Solution:
# (0,6)
# (1,2)
# (2,7)
# (3,1)
# (4,4)
# (5,0)
# (6,5)
# (7,3)
#
# Success , Elapsed Time: 11.339ms
#
# Unsuccessful, Elapsed Time: 311.941ms
# Unsuccessful, Elapsed Time: 358.348ms
# Unsuccessful, Elapsed Time: 329.977ms
# Unsuccessful, Elapsed Time: 358.652ms
# Unsuccessful, Elapsed Time: 339.386ms
# Solution:
# (0,1)
# (1,3)
# (2,5)
# (3,7)
# (4,2)
# (5,0)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 1.899ms
#
# Unsuccessful, Elapsed Time: 296.357ms
# Unsuccessful, Elapsed Time: 339.821ms
# Solution:
# (0,3)
# (1,0)
# (2,4)
# (3,7)
# (4,5)
# (5,2)
# (6,6)
# (7,1)
#
# Success , Elapsed Time: 4.702ms
#
# Unsuccessful, Elapsed Time: 340.706ms
# Unsuccessful, Elapsed Time: 312.666ms
# Unsuccessful, Elapsed Time: 300.57ms
# Unsuccessful, Elapsed Time: 333.469ms
# Unsuccessful, Elapsed Time: 245.431ms
# Unsuccessful, Elapsed Time: 373.288ms
# Unsuccessful, Elapsed Time: 335.114ms
# Solution:
# (0,3)
# (1,1)
# (2,6)
# (3,2)
# (4,5)
# (5,7)
# (6,4)
# (7,0)
#
# Success , Elapsed Time: 0.7ms
#
# Solution:
# (0,4)
# (1,1)
# (2,7)
# (3,0)
# (4,3)
# (5,6)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 6.956ms
#
# Unsuccessful, Elapsed Time: 351.929ms
# Unsuccessful, Elapsed Time: 297.591ms
# Unsuccessful, Elapsed Time: 316.824ms
# Solution:
# (0,4)
# (1,6)
# (2,1)
# (3,5)
# (4,2)
# (5,0)
# (6,7)
# (7,3)
#
# Success , Elapsed Time: 23.011ms
#
# Solution:
# (0,2)
# (1,0)
# (2,6)
# (3,4)
# (4,7)
# (5,1)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 0.279ms
#
# Unsuccessful, Elapsed Time: 365.501ms
# Unsuccessful, Elapsed Time: 357.034ms
# Unsuccessful, Elapsed Time: 319.738ms
# Unsuccessful, Elapsed Time: 310.346ms
# Unsuccessful, Elapsed Time: 325.248ms
# Unsuccessful, Elapsed Time: 270.282ms
# Unsuccessful, Elapsed Time: 385.329ms
# Unsuccessful, Elapsed Time: 378.596ms
# Unsuccessful, Elapsed Time: 283.951ms
# Unsuccessful, Elapsed Time: 342.589ms
# Unsuccessful, Elapsed Time: 381.873ms
# Unsuccessful, Elapsed Time: 357.94ms
# Unsuccessful, Elapsed Time: 344.809ms
# Unsuccessful, Elapsed Time: 300.505ms
# Unsuccessful, Elapsed Time: 299.335ms
# Unsuccessful, Elapsed Time: 356.228ms
# Unsuccessful, Elapsed Time: 377.339ms
# Unsuccessful, Elapsed Time: 327.929ms
# Unsuccessful, Elapsed Time: 300.652ms
# Unsuccessful, Elapsed Time: 362.958ms
# Unsuccessful, Elapsed Time: 327.721ms
# Unsuccessful, Elapsed Time: 358.794ms
# Solution:
# (0,1)
# (1,5)
# (2,0)
# (3,6)
# (4,3)
# (5,7)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 41.866ms
#
# Unsuccessful, Elapsed Time: 269.264ms
# Unsuccessful, Elapsed Time: 311.941ms
# Unsuccessful, Elapsed Time: 256.764ms
# Unsuccessful, Elapsed Time: 266.146ms
# Unsuccessful, Elapsed Time: 362.402ms
# Unsuccessful, Elapsed Time: 366.877ms
# Unsuccessful, Elapsed Time: 319.776ms
# Unsuccessful, Elapsed Time: 377.81ms
# Solution:
# (0,3)
# (1,0)
# (2,4)
# (3,7)
# (4,1)
# (5,6)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 1.384ms
#
# Solution:
# (0,4)
# (1,2)
# (2,0)
# (3,5)
# (4,7)
# (5,1)
# (6,3)
# (7,6)
#
# Success , Elapsed Time: 20.273ms
#
# Solution:
# (0,1)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,3)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 14.629ms
#
# Solution:
# (0,5)
# (1,3)
# (2,1)
# (3,7)
# (4,4)
# (5,6)
# (6,0)
# (7,2)
#
# Success , Elapsed Time: 0.547ms
#
# Unsuccessful, Elapsed Time: 308.237ms
# Unsuccessful, Elapsed Time: 365.066ms
# Unsuccessful, Elapsed Time: 355.44ms
# Unsuccessful, Elapsed Time: 278.237ms
# Unsuccessful, Elapsed Time: 376.667ms
# Unsuccessful, Elapsed Time: 363.269ms
# Unsuccessful, Elapsed Time: 305.662ms
# Unsuccessful, Elapsed Time: 333.221ms
# Unsuccessful, Elapsed Time: 404.295ms
# Unsuccessful, Elapsed Time: 362.84ms
# Unsuccessful, Elapsed Time: 390.082ms
# Unsuccessful, Elapsed Time: 289.866ms
# Unsuccessful, Elapsed Time: 373.298ms
# Solution:
# (0,2)
# (1,6)
# (2,1)
# (3,7)
# (4,5)
# (5,3)
# (6,0)
# (7,4)
#
# Success , Elapsed Time: 5.08ms
#
# Unsuccessful, Elapsed Time: 334.48ms
# Solution:
# (0,5)
# (1,3)
# (2,6)
# (3,0)
# (4,7)
# (5,1)
# (6,4)
# (7,2)
#
# Success , Elapsed Time: 2.601ms
#
# Unsuccessful, Elapsed Time: 293.256ms
# Unsuccessful, Elapsed Time: 323.382ms
# Unsuccessful, Elapsed Time: 278.77ms
# Unsuccessful, Elapsed Time: 260.812ms
# Solution:
# (0,5)
# (1,0)
# (2,4)
# (3,1)
# (4,7)
# (5,2)
# (6,6)
# (7,3)
#
# Success , Elapsed Time: 4.987ms
#
# Unsuccessful, Elapsed Time: 302.139ms
# Unsuccessful, Elapsed Time: 290.989ms
# Unsuccessful, Elapsed Time: 367.117ms
# Solution:
# (0,2)
# (1,7)
# (2,3)
# (3,6)
# (4,0)
# (5,5)
# (6,1)
# (7,4)
#
# Success , Elapsed Time: 6.729ms
#
# Unsuccessful, Elapsed Time: 357.443ms
# Unsuccessful, Elapsed Time: 321.172ms
# Unsuccessful, Elapsed Time: 350.712ms
# Unsuccessful, Elapsed Time: 333.219ms
# Unsuccessful, Elapsed Time: 352.646ms
# Unsuccessful, Elapsed Time: 355.975ms
# Unsuccessful, Elapsed Time: 387.017ms
# Unsuccessful, Elapsed Time: 327.205ms
# Unsuccessful, Elapsed Time: 329.274ms
# Unsuccessful, Elapsed Time: 341.032ms
# Unsuccessful, Elapsed Time: 326.898ms
# Unsuccessful, Elapsed Time: 329.079ms
# Unsuccessful, Elapsed Time: 357.254ms
# Unsuccessful, Elapsed Time: 299.872ms
# Solution:
# (0,2)
# (1,4)
# (2,7)
# (3,3)
# (4,0)
# (5,6)
# (6,1)
# (7,5)
#
# Success , Elapsed Time: 1.696ms
#
# Unsuccessful, Elapsed Time: 399.065ms
# Unsuccessful, Elapsed Time: 348.318ms
# Unsuccessful, Elapsed Time: 292.514ms
# Unsuccessful, Elapsed Time: 326.592ms
# Unsuccessful, Elapsed Time: 360.523ms
# Unsuccessful, Elapsed Time: 280.595ms
# Unsuccessful, Elapsed Time: 223.203ms
# Unsuccessful, Elapsed Time: 402.449ms
# Unsuccessful, Elapsed Time: 378.415ms
# Unsuccessful, Elapsed Time: 295.142ms
# Unsuccessful, Elapsed Time: 290.822ms
# Unsuccessful, Elapsed Time: 321.864ms
# Unsuccessful, Elapsed Time: 270.248ms
# Unsuccessful, Elapsed Time: 264.839ms
# Unsuccessful, Elapsed Time: 323.845ms
# Unsuccessful, Elapsed Time: 298.001ms
# Unsuccessful, Elapsed Time: 360.316ms
# Unsuccessful, Elapsed Time: 347.027ms
# Unsuccessful, Elapsed Time: 303.114ms
# Unsuccessful, Elapsed Time: 408.971ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 0.415ms
#
# Unsuccessful, Elapsed Time: 170.663ms
# Unsuccessful, Elapsed Time: 334.765ms
# Unsuccessful, Elapsed Time: 368.639ms
# Unsuccessful, Elapsed Time: 350.967ms
# Unsuccessful, Elapsed Time: 277.793ms
# Unsuccessful, Elapsed Time: 388.974ms
# Unsuccessful, Elapsed Time: 304.063ms
# Solution:
# (0,4)
# (1,1)
# (2,3)
# (3,6)
# (4,2)
# (5,7)
# (6,5)
# (7,0)
#
# Success , Elapsed Time: 1.114ms
#
# Unsuccessful, Elapsed Time: 332.881ms
# Unsuccessful, Elapsed Time: 360.15ms
# Unsuccessful, Elapsed Time: 310.577ms
# Unsuccessful, Elapsed Time: 374.513ms
# Unsuccessful, Elapsed Time: 385.641ms
# Unsuccessful, Elapsed Time: 336.46ms
# Unsuccessful, Elapsed Time: 347.084ms
# Unsuccessful, Elapsed Time: 111.4ms
# Unsuccessful, Elapsed Time: 331.481ms
# Unsuccessful, Elapsed Time: 346.704ms
# Solution:
# (0,2)
# (1,0)
# (2,6)
# (3,4)
# (4,7)
# (5,1)
# (6,3)
# (7,5)
#
# Success , Elapsed Time: 26.858ms
#
# Unsuccessful, Elapsed Time: 351.557ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,1)
# (4,6)
# (5,0)
# (6,2)
# (7,4)
#
# Success , Elapsed Time: 17.095ms
#
# Unsuccessful, Elapsed Time: 329.926ms
# Unsuccessful, Elapsed Time: 323.996ms
# Unsuccessful, Elapsed Time: 316.974ms
# Unsuccessful, Elapsed Time: 362.376ms
# Unsuccessful, Elapsed Time: 317.606ms
# Unsuccessful, Elapsed Time: 338.492ms
# Unsuccessful, Elapsed Time: 385.487ms
# Unsuccessful, Elapsed Time: 358.345ms
# Unsuccessful, Elapsed Time: 398.366ms
# Unsuccessful, Elapsed Time: 347.512ms
# Unsuccessful, Elapsed Time: 342.361ms
# Unsuccessful, Elapsed Time: 387.377ms
# Unsuccessful, Elapsed Time: 275.083ms
# Unsuccessful, Elapsed Time: 363.95ms
# Unsuccessful, Elapsed Time: 329.967ms
# Unsuccessful, Elapsed Time: 354.495ms
# Unsuccessful, Elapsed Time: 348.485ms
# Unsuccessful, Elapsed Time: 346.096ms
# Unsuccessful, Elapsed Time: 368.149ms
# Unsuccessful, Elapsed Time: 353.426ms
# Unsuccessful, Elapsed Time: 349.352ms
# Unsuccessful, Elapsed Time: 309.779ms
# Unsuccessful, Elapsed Time: 310.36ms
# Unsuccessful, Elapsed Time: 284.145ms
# Unsuccessful, Elapsed Time: 291.511ms
# Unsuccessful, Elapsed Time: 335.191ms
# Unsuccessful, Elapsed Time: 188.43ms
# Unsuccessful, Elapsed Time: 361.704ms
# Unsuccessful, Elapsed Time: 317.683ms
# Unsuccessful, Elapsed Time: 399.402ms
# Unsuccessful, Elapsed Time: 345.969ms
# Solution:
# (0,3)
# (1,5)
# (2,7)
# (3,2)
# (4,0)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 8.109ms
#
# Unsuccessful, Elapsed Time: 319.978ms
# Unsuccessful, Elapsed Time: 293.348ms
# Unsuccessful, Elapsed Time: 230.189ms
# Unsuccessful, Elapsed Time: 335.723ms
# Solution:
# (0,3)
# (1,6)
# (2,4)
# (3,1)
# (4,5)
# (5,0)
# (6,2)
# (7,7)
#
# Success , Elapsed Time: 11.873ms
#
# Unsuccessful, Elapsed Time: 331.986ms
# Unsuccessful, Elapsed Time: 310.582ms
# Unsuccessful, Elapsed Time: 383.876ms
# Unsuccessful, Elapsed Time: 360.569ms
# Unsuccessful, Elapsed Time: 318.138ms
# Unsuccessful, Elapsed Time: 344.781ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,0)
# (4,3)
# (5,6)
# (6,4)
# (7,1)
#
# Success , Elapsed Time: 7.829ms
#
# Unsuccessful, Elapsed Time: 356.31ms
# Unsuccessful, Elapsed Time: 370.205ms
# Unsuccessful, Elapsed Time: 371.974ms
# Unsuccessful, Elapsed Time: 342.635ms
# Unsuccessful, Elapsed Time: 412.37ms
# Unsuccessful, Elapsed Time: 393.829ms
# Unsuccessful, Elapsed Time: 180.073ms
# Unsuccessful, Elapsed Time: 339.734ms
# Unsuccessful, Elapsed Time: 335.666ms
# Unsuccessful, Elapsed Time: 199.1ms
# Unsuccessful, Elapsed Time: 321.181ms
# Unsuccessful, Elapsed Time: 360.094ms
# Unsuccessful, Elapsed Time: 261.554ms
# Unsuccessful, Elapsed Time: 367.023ms
# Unsuccessful, Elapsed Time: 371.539ms
# Unsuccessful, Elapsed Time: 382.722ms
# Unsuccessful, Elapsed Time: 328.433ms
# Unsuccessful, Elapsed Time: 326.934ms
# Unsuccessful, Elapsed Time: 336.966ms
# Unsuccessful, Elapsed Time: 317.74ms
# Unsuccessful, Elapsed Time: 278.941ms
# Unsuccessful, Elapsed Time: 341.518ms
# Solution:
# (0,5)
# (1,2)
# (2,0)
# (3,7)
# (4,3)
# (5,1)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 24.289ms
#
# Unsuccessful, Elapsed Time: 293.601ms
# Unsuccessful, Elapsed Time: 326.402ms
# Unsuccessful, Elapsed Time: 312.197ms
# Unsuccessful, Elapsed Time: 388.274ms
# Unsuccessful, Elapsed Time: 237.899ms
# Unsuccessful, Elapsed Time: 309.501ms
# Unsuccessful, Elapsed Time: 272.348ms
# Unsuccessful, Elapsed Time: 324.131ms
# Unsuccessful, Elapsed Time: 325.3ms
# Unsuccessful, Elapsed Time: 348.752ms
# Unsuccessful, Elapsed Time: 315.543ms
# Unsuccessful, Elapsed Time: 338.029ms
# Unsuccessful, Elapsed Time: 339.243ms
# Unsuccessful, Elapsed Time: 324.531ms
# Unsuccessful, Elapsed Time: 345.461ms
# Solution:
# (0,2)
# (1,5)
# (2,7)
# (3,1)
# (4,3)
# (5,0)
# (6,6)
# (7,4)
#
# Success , Elapsed Time: 0.976ms
#
# Unsuccessful, Elapsed Time: 363.224ms
# Unsuccessful, Elapsed Time: 314.533ms
# Unsuccessful, Elapsed Time: 334.874ms
# Unsuccessful, Elapsed Time: 352.959ms
# Unsuccessful, Elapsed Time: 325.002ms
# Solution:
# (0,2)
# (1,5)
# (2,3)
# (3,0)
# (4,7)
# (5,4)
# (6,6)
# (7,1)
#
# Success , Elapsed Time: 4.12ms
#
# Unsuccessful, Elapsed Time: 341.223ms
# Unsuccessful, Elapsed Time: 208.604ms
# Unsuccessful, Elapsed Time: 356.573ms
# Unsuccessful, Elapsed Time: 396.564ms
# Unsuccessful, Elapsed Time: 388.885ms
# Unsuccessful, Elapsed Time: 354.596ms
# Unsuccessful, Elapsed Time: 343.141ms
# Unsuccessful, Elapsed Time: 330.824ms
# Solution:
# (0,4)
# (1,0)
# (2,7)
# (3,3)
# (4,1)
# (5,6)
# (6,2)
# (7,5)
#
# Success , Elapsed Time: 4.643ms
#
# Solution:
# (0,4)
# (1,2)
# (2,7)
# (3,3)
# (4,6)
# (5,0)
# (6,5)
# (7,1)
#
# Success , Elapsed Time: 15.749ms
#
# Unsuccessful, Elapsed Time: 335.617ms
# Unsuccessful, Elapsed Time: 318.365ms
# Unsuccessful, Elapsed Time: 297.249ms
# Settings		Average Time to Convergence	Success Rate
# Setting 1		9.141ms			13.90%
# Setting 2		11.010ms			12.60%
# Setting 3		9.426ms			11.50%
